# %%
# coding: utf-8
import sys
sys.path.append('..')
from common import config
# GPU에서 실행하려면 아래 주석을 해제하세요(CuPy 필요).
# ==============================================
config.GPU = True
# ==============================================
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity, to_gpu
from dataset import ptb
from ch06.better_rnnlm import BetterRnnlm


# 하이퍼파라미터 설정
batch_size = 20
wordvec_size = 650
hidden_size = 650
time_size = 35
lr = 20.0
max_epoch = 40
max_grad = 0.25
dropout = 0.5

# 학습 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_val, _, _ = ptb.load_data('val')
corpus_test, _, _ = ptb.load_data('test')

if config.GPU:
    corpus = to_gpu(corpus)
    corpus_val = to_gpu(corpus_val)
    corpus_test = to_gpu(corpus_test)

vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

model = BetterRnnlm(vocab_size, wordvec_size, hidden_size, dropout)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

best_ppl = float('inf')
for epoch in range(max_epoch):
    trainer.fit(xs, ts, max_epoch=1, batch_size=batch_size,
                time_size=time_size, max_grad=max_grad)

    model.reset_state()
    ppl = eval_perplexity(model, corpus_val)
    print('검증 퍼플렉서티: ', ppl)

    if best_ppl > ppl:
        best_ppl = ppl
        model.save_params()
    else:
        lr /= 4.0
        optimizer.lr = lr

    model.reset_state()
    print('-' * 50)


# 테스트 데이터로 평가
model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)
print('테스트 퍼플렉서티: ', ppl_test)
# Out:
# ------------------------------------------------------------
#                        GPU Mode (cupy)
# ------------------------------------------------------------
#
# | 에폭 1 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 10000.13
# | 에폭 1 |  반복 21 / 1327 | 시간 7[s] | 퍼플렉서티 3543.91
# | 에폭 1 |  반복 41 / 1327 | 시간 14[s] | 퍼플렉서티 2018.16
# | 에폭 1 |  반복 61 / 1327 | 시간 20[s] | 퍼플렉서티 1308.66
# | 에폭 1 |  반복 81 / 1327 | 시간 26[s] | 퍼플렉서티 1017.54
# | 에폭 1 |  반복 101 / 1327 | 시간 32[s] | 퍼플렉서티 834.48
# | 에폭 1 |  반복 121 / 1327 | 시간 39[s] | 퍼플렉서티 797.66
# | 에폭 1 |  반복 141 / 1327 | 시간 45[s] | 퍼플렉서티 714.55
# | 에폭 1 |  반복 161 / 1327 | 시간 51[s] | 퍼플렉서티 705.18
# | 에폭 1 |  반복 181 / 1327 | 시간 57[s] | 퍼플렉서티 675.86
# | 에폭 1 |  반복 201 / 1327 | 시간 65[s] | 퍼플렉서티 607.12
# | 에폭 1 |  반복 221 / 1327 | 시간 73[s] | 퍼플렉서티 588.00
# | 에폭 1 |  반복 241 / 1327 | 시간 79[s] | 퍼플렉서티 531.64
# | 에폭 1 |  반복 261 / 1327 | 시간 86[s] | 퍼플렉서티 532.84
# | 에폭 1 |  반복 281 / 1327 | 시간 93[s] | 퍼플렉서티 522.38
# | 에폭 1 |  반복 301 / 1327 | 시간 99[s] | 퍼플렉서티 458.52
# | 에폭 1 |  반복 321 / 1327 | 시간 105[s] | 퍼플렉서티 393.81
# | 에폭 1 |  반복 341 / 1327 | 시간 111[s] | 퍼플렉서티 457.47
# | 에폭 1 |  반복 361 / 1327 | 시간 117[s] | 퍼플렉서티 469.93
# | 에폭 1 |  반복 381 / 1327 | 시간 124[s] | 퍼플렉서티 385.24
# | 에폭 1 |  반복 401 / 1327 | 시간 130[s] | 퍼플렉서티 406.08
# | 에폭 1 |  반복 421 / 1327 | 시간 137[s] | 퍼플렉서티 401.19
# | 에폭 1 |  반복 441 / 1327 | 시간 143[s] | 퍼플렉서티 379.82
# | 에폭 1 |  반복 461 / 1327 | 시간 149[s] | 퍼플렉서티 374.47
# | 에폭 1 |  반복 481 / 1327 | 시간 156[s] | 퍼플렉서티 352.17
# | 에폭 1 |  반복 501 / 1327 | 시간 162[s] | 퍼플렉서티 362.52
# | 에폭 1 |  반복 521 / 1327 | 시간 168[s] | 퍼플렉서티 344.99
# | 에폭 1 |  반복 541 / 1327 | 시간 175[s] | 퍼플렉서티 366.08
# | 에폭 1 |  반복 561 / 1327 | 시간 181[s] | 퍼플렉서티 329.35
# | 에폭 1 |  반복 581 / 1327 | 시간 187[s] | 퍼플렉서티 295.26
# | 에폭 1 |  반복 601 / 1327 | 시간 194[s] | 퍼플렉서티 381.39
# | 에폭 1 |  반복 621 / 1327 | 시간 200[s] | 퍼플렉서티 346.38
# | 에폭 1 |  반복 641 / 1327 | 시간 207[s] | 퍼플렉서티 315.84
# | 에폭 1 |  반복 661 / 1327 | 시간 213[s] | 퍼플렉서티 307.11
# | 에폭 1 |  반복 681 / 1327 | 시간 220[s] | 퍼플렉서티 257.09
# | 에폭 1 |  반복 701 / 1327 | 시간 226[s] | 퍼플렉서티 280.81
# | 에폭 1 |  반복 721 / 1327 | 시간 232[s] | 퍼플렉서티 291.80
# | 에폭 1 |  반복 741 / 1327 | 시간 239[s] | 퍼플렉서티 248.49
# | 에폭 1 |  반복 761 / 1327 | 시간 245[s] | 퍼플렉서티 261.86
# | 에폭 1 |  반복 781 / 1327 | 시간 251[s] | 퍼플렉서티 245.52
# | 에폭 1 |  반복 801 / 1327 | 시간 258[s] | 퍼플렉서티 270.13
# | 에폭 1 |  반복 821 / 1327 | 시간 264[s] | 퍼플렉서티 251.54
# | 에폭 1 |  반복 841 / 1327 | 시간 271[s] | 퍼플렉서티 258.77
# | 에폭 1 |  반복 861 / 1327 | 시간 277[s] | 퍼플렉서티 249.03
# | 에폭 1 |  반복 881 / 1327 | 시간 283[s] | 퍼플렉서티 232.09
# | 에폭 1 |  반복 901 / 1327 | 시간 290[s] | 퍼플렉서티 284.20
# | 에폭 1 |  반복 921 / 1327 | 시간 296[s] | 퍼플렉서티 255.86
# | 에폭 1 |  반복 941 / 1327 | 시간 303[s] | 퍼플렉서티 255.66
# | 에폭 1 |  반복 961 / 1327 | 시간 309[s] | 퍼플렉서티 273.64
# | 에폭 1 |  반복 981 / 1327 | 시간 316[s] | 퍼플렉서티 256.30
# | 에폭 1 |  반복 1001 / 1327 | 시간 322[s] | 퍼플렉서티 217.10
# | 에폭 1 |  반복 1021 / 1327 | 시간 328[s] | 퍼플렉서티 250.95
# | 에폭 1 |  반복 1041 / 1327 | 시간 335[s] | 퍼플렉서티 230.39
# | 에폭 1 |  반복 1061 / 1327 | 시간 341[s] | 퍼플렉서티 220.45
# | 에폭 1 |  반복 1081 / 1327 | 시간 348[s] | 퍼플렉서티 189.60
# | 에폭 1 |  반복 1101 / 1327 | 시간 354[s] | 퍼플렉서티 213.71
# | 에폭 1 |  반복 1121 / 1327 | 시간 361[s] | 퍼플렉서티 255.58
# | 에폭 1 |  반복 1141 / 1327 | 시간 367[s] | 퍼플렉서티 233.55
# | 에폭 1 |  반복 1161 / 1327 | 시간 374[s] | 퍼플렉서티 221.44
# | 에폭 1 |  반복 1181 / 1327 | 시간 380[s] | 퍼플렉서티 210.26
# | 에폭 1 |  반복 1201 / 1327 | 시간 387[s] | 퍼플렉서티 180.57
# | 에폭 1 |  반복 1221 / 1327 | 시간 393[s] | 퍼플렉서티 178.95
# | 에폭 1 |  반복 1241 / 1327 | 시간 400[s] | 퍼플렉서티 209.44
# | 에폭 1 |  반복 1261 / 1327 | 시간 406[s] | 퍼플렉서티 190.73
# | 에폭 1 |  반복 1281 / 1327 | 시간 413[s] | 퍼플렉서티 198.59
# | 에폭 1 |  반복 1301 / 1327 | 시간 419[s] | 퍼플렉서티 248.66
# | 에폭 1 |  반복 1321 / 1327 | 시간 426[s] | 퍼플렉서티 230.23
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  204.70296
# --------------------------------------------------
# | 에폭 2 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 300.43
# | 에폭 2 |  반복 21 / 1327 | 시간 6[s] | 퍼플렉서티 231.12
# | 에폭 2 |  반복 41 / 1327 | 시간 13[s] | 퍼플렉서티 214.42
# | 에폭 2 |  반복 61 / 1327 | 시간 19[s] | 퍼플렉서티 195.96
# | 에폭 2 |  반복 81 / 1327 | 시간 26[s] | 퍼플렉서티 178.22
# | 에폭 2 |  반복 101 / 1327 | 시간 32[s] | 퍼플렉서티 168.56
# | 에폭 2 |  반복 121 / 1327 | 시간 38[s] | 퍼플렉서티 183.04
# | 에폭 2 |  반복 141 / 1327 | 시간 45[s] | 퍼플렉서티 201.85
# | 에폭 2 |  반복 161 / 1327 | 시간 52[s] | 퍼플렉서티 216.43
# | 에폭 2 |  반복 181 / 1327 | 시간 58[s] | 퍼플렉서티 224.60
# | 에폭 2 |  반복 201 / 1327 | 시간 65[s] | 퍼플렉서티 207.72
# | 에폭 2 |  반복 221 / 1327 | 시간 71[s] | 퍼플렉서티 205.06
# | 에폭 2 |  반복 241 / 1327 | 시간 78[s] | 퍼플렉서티 196.39
# | 에폭 2 |  반복 261 / 1327 | 시간 84[s] | 퍼플렉서티 213.14
# | 에폭 2 |  반복 281 / 1327 | 시간 91[s] | 퍼플렉서티 206.60
# | 에폭 2 |  반복 301 / 1327 | 시간 97[s] | 퍼플렉서티 188.02
# | 에폭 2 |  반복 321 / 1327 | 시간 104[s] | 퍼플렉서티 156.73
# | 에폭 2 |  반복 341 / 1327 | 시간 111[s] | 퍼플렉서티 201.15
# | 에폭 2 |  반복 361 / 1327 | 시간 118[s] | 퍼플렉서티 217.10
# | 에폭 2 |  반복 381 / 1327 | 시간 124[s] | 퍼플렉서티 173.44
# | 에폭 2 |  반복 401 / 1327 | 시간 131[s] | 퍼플렉서티 196.10
# | 에폭 2 |  반복 421 / 1327 | 시간 137[s] | 퍼플렉서티 177.43
# | 에폭 2 |  반복 441 / 1327 | 시간 144[s] | 퍼플렉서티 180.77
# | 에폭 2 |  반복 461 / 1327 | 시간 150[s] | 퍼플렉서티 184.20
# | 에폭 2 |  반복 481 / 1327 | 시간 157[s] | 퍼플렉서티 178.24
# | 에폭 2 |  반복 501 / 1327 | 시간 163[s] | 퍼플렉서티 193.02
# | 에폭 2 |  반복 521 / 1327 | 시간 170[s] | 퍼플렉서티 192.04
# | 에폭 2 |  반복 541 / 1327 | 시간 177[s] | 퍼플렉서티 203.12
# | 에폭 2 |  반복 561 / 1327 | 시간 184[s] | 퍼플렉서티 173.38
# | 에폭 2 |  반복 581 / 1327 | 시간 191[s] | 퍼플렉서티 159.88
# | 에폭 2 |  반복 601 / 1327 | 시간 198[s] | 퍼플렉서티 214.14
# | 에폭 2 |  반복 621 / 1327 | 시간 205[s] | 퍼플렉서티 204.43
# | 에폭 2 |  반복 641 / 1327 | 시간 211[s] | 퍼플렉서티 183.87
# | 에폭 2 |  반복 661 / 1327 | 시간 218[s] | 퍼플렉서티 175.56
# | 에폭 2 |  반복 681 / 1327 | 시간 225[s] | 퍼플렉서티 149.73
# | 에폭 2 |  반복 701 / 1327 | 시간 231[s] | 퍼플렉서티 169.52
# | 에폭 2 |  반복 721 / 1327 | 시간 238[s] | 퍼플렉서티 175.10
# | 에폭 2 |  반복 741 / 1327 | 시간 244[s] | 퍼플렉서티 150.05
# | 에폭 2 |  반복 761 / 1327 | 시간 251[s] | 퍼플렉서티 152.18
# | 에폭 2 |  반복 781 / 1327 | 시간 258[s] | 퍼플렉서티 151.59
# | 에폭 2 |  반복 801 / 1327 | 시간 264[s] | 퍼플렉서티 169.37
# | 에폭 2 |  반복 821 / 1327 | 시간 271[s] | 퍼플렉서티 164.29
# | 에폭 2 |  반복 841 / 1327 | 시간 277[s] | 퍼플렉서티 164.76
# | 에폭 2 |  반복 861 / 1327 | 시간 284[s] | 퍼플렉서티 161.99
# | 에폭 2 |  반복 881 / 1327 | 시간 290[s] | 퍼플렉서티 149.54
# | 에폭 2 |  반복 901 / 1327 | 시간 297[s] | 퍼플렉서티 188.16
# | 에폭 2 |  반복 921 / 1327 | 시간 304[s] | 퍼플렉서티 166.60
# | 에폭 2 |  반복 941 / 1327 | 시간 310[s] | 퍼플렉서티 170.24
# | 에폭 2 |  반복 961 / 1327 | 시간 317[s] | 퍼플렉서티 186.33
# | 에폭 2 |  반복 981 / 1327 | 시간 323[s] | 퍼플렉서티 174.97
# | 에폭 2 |  반복 1001 / 1327 | 시간 330[s] | 퍼플렉서티 150.41
# | 에폭 2 |  반복 1021 / 1327 | 시간 337[s] | 퍼플렉서티 176.53
# | 에폭 2 |  반복 1041 / 1327 | 시간 343[s] | 퍼플렉서티 158.96
# | 에폭 2 |  반복 1061 / 1327 | 시간 350[s] | 퍼플렉서티 148.20
# | 에폭 2 |  반복 1081 / 1327 | 시간 358[s] | 퍼플렉서티 124.65
# | 에폭 2 |  반복 1101 / 1327 | 시간 365[s] | 퍼플렉서티 138.62
# | 에폭 2 |  반복 1121 / 1327 | 시간 371[s] | 퍼플렉서티 174.55
# | 에폭 2 |  반복 1141 / 1327 | 시간 378[s] | 퍼플렉서티 162.48
# | 에폭 2 |  반복 1161 / 1327 | 시간 384[s] | 퍼플렉서티 148.53
# | 에폭 2 |  반복 1181 / 1327 | 시간 391[s] | 퍼플렉서티 149.00
# | 에폭 2 |  반복 1201 / 1327 | 시간 397[s] | 퍼플렉서티 127.22
# | 에폭 2 |  반복 1221 / 1327 | 시간 404[s] | 퍼플렉서티 127.33
# | 에폭 2 |  반복 1241 / 1327 | 시간 411[s] | 퍼플렉서티 148.81
# | 에폭 2 |  반복 1261 / 1327 | 시간 417[s] | 퍼플렉서티 137.78
# | 에폭 2 |  반복 1281 / 1327 | 시간 424[s] | 퍼플렉서티 140.81
# | 에폭 2 |  반복 1301 / 1327 | 시간 430[s] | 퍼플렉서티 178.75
# | 에폭 2 |  반복 1321 / 1327 | 시간 437[s] | 퍼플렉서티 171.74
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  147.7757
# --------------------------------------------------
# | 에폭 3 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 222.64
# | 에폭 3 |  반복 21 / 1327 | 시간 6[s] | 퍼플렉서티 160.32
# | 에폭 3 |  반복 41 / 1327 | 시간 13[s] | 퍼플렉서티 151.11
# | 에폭 3 |  반복 61 / 1327 | 시간 19[s] | 퍼플렉서티 143.64
# | 에폭 3 |  반복 81 / 1327 | 시간 26[s] | 퍼플렉서티 127.64
# | 에폭 3 |  반복 101 / 1327 | 시간 33[s] | 퍼플렉서티 121.81
# | 에폭 3 |  반복 121 / 1327 | 시간 39[s] | 퍼플렉서티 133.26
# | 에폭 3 |  반복 141 / 1327 | 시간 46[s] | 퍼플렉서티 147.02
# | 에폭 3 |  반복 161 / 1327 | 시간 52[s] | 퍼플렉서티 161.40
# | 에폭 3 |  반복 181 / 1327 | 시간 59[s] | 퍼플렉서티 171.02
# | 에폭 3 |  반복 201 / 1327 | 시간 65[s] | 퍼플렉서티 160.85
# | 에폭 3 |  반복 221 / 1327 | 시간 72[s] | 퍼플렉서티 157.74
# | 에폭 3 |  반복 241 / 1327 | 시간 79[s] | 퍼플렉서티 150.01
# | 에폭 3 |  반복 261 / 1327 | 시간 85[s] | 퍼플렉서티 163.39
# | 에폭 3 |  반복 281 / 1327 | 시간 92[s] | 퍼플렉서티 158.61
# | 에폭 3 |  반복 301 / 1327 | 시간 98[s] | 퍼플렉서티 140.76
# | 에폭 3 |  반복 321 / 1327 | 시간 105[s] | 퍼플렉서티 111.78
# | 에폭 3 |  반복 341 / 1327 | 시간 112[s] | 퍼플렉서티 152.89
# | 에폭 3 |  반복 361 / 1327 | 시간 118[s] | 퍼플렉서티 165.87
# | 에폭 3 |  반복 381 / 1327 | 시간 125[s] | 퍼플렉서티 129.86
# | 에폭 3 |  반복 401 / 1327 | 시간 131[s] | 퍼플렉서티 151.70
# | 에폭 3 |  반복 421 / 1327 | 시간 138[s] | 퍼플렉서티 131.88
# | 에폭 3 |  반복 441 / 1327 | 시간 144[s] | 퍼플렉서티 139.99
# | 에폭 3 |  반복 461 / 1327 | 시간 150[s] | 퍼플렉서티 139.19
# | 에폭 3 |  반복 481 / 1327 | 시간 157[s] | 퍼플렉서티 135.10
# | 에폭 3 |  반복 501 / 1327 | 시간 163[s] | 퍼플렉서티 148.94
# | 에폭 3 |  반복 521 / 1327 | 시간 170[s] | 퍼플렉서티 152.46
# | 에폭 3 |  반복 541 / 1327 | 시간 176[s] | 퍼플렉서티 160.01
# | 에폭 3 |  반복 561 / 1327 | 시간 183[s] | 퍼플렉서티 134.60
# | 에폭 3 |  반복 581 / 1327 | 시간 190[s] | 퍼플렉서티 122.09
# | 에폭 3 |  반복 601 / 1327 | 시간 196[s] | 퍼플렉서티 171.28
# | 에폭 3 |  반복 621 / 1327 | 시간 203[s] | 퍼플렉서티 160.92
# | 에폭 3 |  반복 641 / 1327 | 시간 209[s] | 퍼플렉서티 146.21
# | 에폭 3 |  반복 661 / 1327 | 시간 216[s] | 퍼플렉서티 136.44
# | 에폭 3 |  반복 681 / 1327 | 시간 223[s] | 퍼플렉서티 117.67
# | 에폭 3 |  반복 701 / 1327 | 시간 229[s] | 퍼플렉서티 137.32
# | 에폭 3 |  반복 721 / 1327 | 시간 236[s] | 퍼플렉서티 140.23
# | 에폭 3 |  반복 741 / 1327 | 시간 242[s] | 퍼플렉서티 120.77
# | 에폭 3 |  반복 761 / 1327 | 시간 248[s] | 퍼플렉서티 115.40
# | 에폭 3 |  반복 781 / 1327 | 시간 255[s] | 퍼플렉서티 120.99
# | 에폭 3 |  반복 801 / 1327 | 시간 261[s] | 퍼플렉서티 136.70
# | 에폭 3 |  반복 821 / 1327 | 시간 268[s] | 퍼플렉서티 134.72
# | 에폭 3 |  반복 841 / 1327 | 시간 275[s] | 퍼플렉서티 135.25
# | 에폭 3 |  반복 861 / 1327 | 시간 281[s] | 퍼플렉서티 131.93
# | 에폭 3 |  반복 881 / 1327 | 시간 288[s] | 퍼플렉서티 120.53
# | 에폭 3 |  반복 901 / 1327 | 시간 294[s] | 퍼플렉서티 152.97
# | 에폭 3 |  반복 921 / 1327 | 시간 301[s] | 퍼플렉서티 133.88
# | 에폭 3 |  반복 941 / 1327 | 시간 307[s] | 퍼플렉서티 140.13
# | 에폭 3 |  반복 961 / 1327 | 시간 314[s] | 퍼플렉서티 155.29
# | 에폭 3 |  반복 981 / 1327 | 시간 320[s] | 퍼플렉서티 144.96
# | 에폭 3 |  반복 1001 / 1327 | 시간 327[s] | 퍼플렉서티 122.55
# | 에폭 3 |  반복 1021 / 1327 | 시간 333[s] | 퍼플렉서티 147.08
# | 에폭 3 |  반복 1041 / 1327 | 시간 340[s] | 퍼플렉서티 127.87
# | 에폭 3 |  반복 1061 / 1327 | 시간 346[s] | 퍼플렉서티 121.88
# | 에폭 3 |  반복 1081 / 1327 | 시간 353[s] | 퍼플렉서티 102.23
# | 에폭 3 |  반복 1101 / 1327 | 시간 359[s] | 퍼플렉서티 107.52
# | 에폭 3 |  반복 1121 / 1327 | 시간 366[s] | 퍼플렉서티 142.73
# | 에폭 3 |  반복 1141 / 1327 | 시간 372[s] | 퍼플렉서티 133.29
# | 에폭 3 |  반복 1161 / 1327 | 시간 379[s] | 퍼플렉서티 117.47
# | 에폭 3 |  반복 1181 / 1327 | 시간 385[s] | 퍼플렉서티 124.14
# | 에폭 3 |  반복 1201 / 1327 | 시간 392[s] | 퍼플렉서티 104.82
# | 에폭 3 |  반복 1221 / 1327 | 시간 398[s] | 퍼플렉서티 104.11
# | 에폭 3 |  반복 1241 / 1327 | 시간 404[s] | 퍼플렉서티 123.81
# | 에폭 3 |  반복 1261 / 1327 | 시간 411[s] | 퍼플렉서티 115.51
# | 에폭 3 |  반복 1281 / 1327 | 시간 417[s] | 퍼플렉서티 117.03
# | 에폭 3 |  반복 1301 / 1327 | 시간 424[s] | 퍼플렉서티 150.19
# | 에폭 3 |  반복 1321 / 1327 | 시간 430[s] | 퍼플렉서티 143.74
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  124.62786
# --------------------------------------------------
# | 에폭 4 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 206.42
# | 에폭 4 |  반복 21 / 1327 | 시간 6[s] | 퍼플렉서티 131.62
# | 에폭 4 |  반복 41 / 1327 | 시간 13[s] | 퍼플렉서티 125.88
# | 에폭 4 |  반복 61 / 1327 | 시간 19[s] | 퍼플렉서티 118.26
# | 에폭 4 |  반복 81 / 1327 | 시간 26[s] | 퍼플렉서티 103.99
# | 에폭 4 |  반복 101 / 1327 | 시간 32[s] | 퍼플렉서티 99.20
# | 에폭 4 |  반복 121 / 1327 | 시간 39[s] | 퍼플렉서티 112.10
# | 에폭 4 |  반복 141 / 1327 | 시간 45[s] | 퍼플렉서티 122.44
# | 에폭 4 |  반복 161 / 1327 | 시간 52[s] | 퍼플렉서티 137.09
# | 에폭 4 |  반복 181 / 1327 | 시간 58[s] | 퍼플렉서티 145.40
# | 에폭 4 |  반복 201 / 1327 | 시간 65[s] | 퍼플렉서티 137.31
# | 에폭 4 |  반복 221 / 1327 | 시간 72[s] | 퍼플렉서티 135.30
# | 에폭 4 |  반복 241 / 1327 | 시간 78[s] | 퍼플렉서티 129.38
# | 에폭 4 |  반복 261 / 1327 | 시간 85[s] | 퍼플렉서티 139.09
# | 에폭 4 |  반복 281 / 1327 | 시간 91[s] | 퍼플렉서티 135.62
# | 에폭 4 |  반복 301 / 1327 | 시간 98[s] | 퍼플렉서티 116.52
# | 에폭 4 |  반복 321 / 1327 | 시간 104[s] | 퍼플렉서티 91.46
# | 에폭 4 |  반복 341 / 1327 | 시간 110[s] | 퍼플렉서티 130.13
# | 에폭 4 |  반복 361 / 1327 | 시간 117[s] | 퍼플렉서티 136.84
# | 에폭 4 |  반복 381 / 1327 | 시간 123[s] | 퍼플렉서티 111.74
# | 에폭 4 |  반복 401 / 1327 | 시간 130[s] | 퍼플렉서티 126.90
# | 에폭 4 |  반복 421 / 1327 | 시간 136[s] | 퍼플렉서티 109.81
# | 에폭 4 |  반복 441 / 1327 | 시간 143[s] | 퍼플렉서티 118.64
# | 에폭 4 |  반복 461 / 1327 | 시간 149[s] | 퍼플렉서티 117.69
# | 에폭 4 |  반복 481 / 1327 | 시간 156[s] | 퍼플렉서티 115.90
# | 에폭 4 |  반복 501 / 1327 | 시간 162[s] | 퍼플렉서티 127.86
# | 에폭 4 |  반복 521 / 1327 | 시간 168[s] | 퍼플렉서티 133.42
# | 에폭 4 |  반복 541 / 1327 | 시간 175[s] | 퍼플렉서티 136.31
# | 에폭 4 |  반복 561 / 1327 | 시간 181[s] | 퍼플렉서티 113.90
# | 에폭 4 |  반복 581 / 1327 | 시간 187[s] | 퍼플렉서티 104.50
# | 에폭 4 |  반복 601 / 1327 | 시간 194[s] | 퍼플렉서티 146.01
# | 에폭 4 |  반복 621 / 1327 | 시간 200[s] | 퍼플렉서티 137.95
# | 에폭 4 |  반복 641 / 1327 | 시간 206[s] | 퍼플렉서티 125.75
# | 에폭 4 |  반복 661 / 1327 | 시간 213[s] | 퍼플렉서티 117.59
# | 에폭 4 |  반복 681 / 1327 | 시간 219[s] | 퍼플렉서티 100.55
# | 에폭 4 |  반복 701 / 1327 | 시간 225[s] | 퍼플렉서티 119.02
# | 에폭 4 |  반복 721 / 1327 | 시간 232[s] | 퍼플렉서티 120.58
# | 에폭 4 |  반복 741 / 1327 | 시간 238[s] | 퍼플렉서티 103.91
# | 에폭 4 |  반복 761 / 1327 | 시간 245[s] | 퍼플렉서티 97.20
# | 에폭 4 |  반복 781 / 1327 | 시간 252[s] | 퍼플렉서티 102.91
# | 에폭 4 |  반복 801 / 1327 | 시간 259[s] | 퍼플렉서티 117.86
# | 에폭 4 |  반복 821 / 1327 | 시간 266[s] | 퍼플렉서티 116.64
# | 에폭 4 |  반복 841 / 1327 | 시간 274[s] | 퍼플렉서티 117.64
# | 에폭 4 |  반복 861 / 1327 | 시간 281[s] | 퍼플렉서티 115.01
# | 에폭 4 |  반복 881 / 1327 | 시간 288[s] | 퍼플렉서티 104.62
# | 에폭 4 |  반복 901 / 1327 | 시간 295[s] | 퍼플렉서티 132.15
# | 에폭 4 |  반복 921 / 1327 | 시간 302[s] | 퍼플렉서티 115.86
# | 에폭 4 |  반복 941 / 1327 | 시간 309[s] | 퍼플렉서티 124.20
# | 에폭 4 |  반복 961 / 1327 | 시간 316[s] | 퍼플렉서티 133.84
# | 에폭 4 |  반복 981 / 1327 | 시간 322[s] | 퍼플렉서티 126.02
# | 에폭 4 |  반복 1001 / 1327 | 시간 329[s] | 퍼플렉서티 108.15
# | 에폭 4 |  반복 1021 / 1327 | 시간 336[s] | 퍼플렉서티 130.06
# | 에폭 4 |  반복 1041 / 1327 | 시간 342[s] | 퍼플렉서티 113.81
# | 에폭 4 |  반복 1061 / 1327 | 시간 349[s] | 퍼플렉서티 105.55
# | 에폭 4 |  반복 1081 / 1327 | 시간 356[s] | 퍼플렉서티 87.31
# | 에폭 4 |  반복 1101 / 1327 | 시간 363[s] | 퍼플렉서티 91.41
# | 에폭 4 |  반복 1121 / 1327 | 시간 369[s] | 퍼플렉서티 122.98
# | 에폭 4 |  반복 1141 / 1327 | 시간 376[s] | 퍼플렉서티 117.20
# | 에폭 4 |  반복 1161 / 1327 | 시간 383[s] | 퍼플렉서티 102.16
# | 에폭 4 |  반복 1181 / 1327 | 시간 389[s] | 퍼플렉서티 108.93
# | 에폭 4 |  반복 1201 / 1327 | 시간 396[s] | 퍼플렉서티 90.55
# | 에폭 4 |  반복 1221 / 1327 | 시간 403[s] | 퍼플렉서티 91.88
# | 에폭 4 |  반복 1241 / 1327 | 시간 410[s] | 퍼플렉서티 108.39
# | 에폭 4 |  반복 1261 / 1327 | 시간 416[s] | 퍼플렉서티 102.57
# | 에폭 4 |  반복 1281 / 1327 | 시간 423[s] | 퍼플렉서티 102.60
# | 에폭 4 |  반복 1301 / 1327 | 시간 430[s] | 퍼플렉서티 132.17
# | 에폭 4 |  반복 1321 / 1327 | 시간 437[s] | 퍼플렉서티 128.77
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  113.49823
# --------------------------------------------------
# | 에폭 5 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 168.56
# | 에폭 5 |  반복 21 / 1327 | 시간 8[s] | 퍼플렉서티 112.30
# | 에폭 5 |  반복 41 / 1327 | 시간 15[s] | 퍼플렉서티 110.04
# | 에폭 5 |  반복 61 / 1327 | 시간 21[s] | 퍼플렉서티 106.79
# | 에폭 5 |  반복 81 / 1327 | 시간 28[s] | 퍼플렉서티 92.41
# | 에폭 5 |  반복 101 / 1327 | 시간 35[s] | 퍼플렉서티 88.86
# | 에폭 5 |  반복 121 / 1327 | 시간 41[s] | 퍼플렉서티 98.59
# | 에폭 5 |  반복 141 / 1327 | 시간 48[s] | 퍼플렉서티 106.72
# | 에폭 5 |  반복 161 / 1327 | 시간 54[s] | 퍼플렉서티 121.89
# | 에폭 5 |  반복 181 / 1327 | 시간 61[s] | 퍼플렉서티 127.97
# | 에폭 5 |  반복 201 / 1327 | 시간 68[s] | 퍼플렉서티 123.40
# | 에폭 5 |  반복 221 / 1327 | 시간 74[s] | 퍼플렉서티 120.02
# | 에폭 5 |  반복 241 / 1327 | 시간 81[s] | 퍼플렉서티 114.71
# | 에폭 5 |  반복 261 / 1327 | 시간 87[s] | 퍼플렉서티 123.65
# | 에폭 5 |  반복 281 / 1327 | 시간 94[s] | 퍼플렉서티 120.30
# | 에폭 5 |  반복 301 / 1327 | 시간 101[s] | 퍼플렉서티 100.43
# | 에폭 5 |  반복 321 / 1327 | 시간 108[s] | 퍼플렉서티 81.80
# | 에폭 5 |  반복 341 / 1327 | 시간 114[s] | 퍼플렉서티 115.03
# | 에폭 5 |  반복 361 / 1327 | 시간 121[s] | 퍼플렉서티 121.67
# | 에폭 5 |  반복 381 / 1327 | 시간 128[s] | 퍼플렉서티 100.08
# | 에폭 5 |  반복 401 / 1327 | 시간 134[s] | 퍼플렉서티 112.79
# | 에폭 5 |  반복 421 / 1327 | 시간 141[s] | 퍼플렉서티 97.54
# | 에폭 5 |  반복 441 / 1327 | 시간 147[s] | 퍼플렉서티 106.44
# | 에폭 5 |  반복 461 / 1327 | 시간 154[s] | 퍼플렉서티 104.86
# | 에폭 5 |  반복 481 / 1327 | 시간 160[s] | 퍼플렉서티 103.38
# | 에폭 5 |  반복 501 / 1327 | 시간 166[s] | 퍼플렉서티 113.94
# | 에폭 5 |  반복 521 / 1327 | 시간 173[s] | 퍼플렉서티 118.93
# | 에폭 5 |  반복 541 / 1327 | 시간 179[s] | 퍼플렉서티 120.75
# | 에폭 5 |  반복 561 / 1327 | 시간 185[s] | 퍼플렉서티 101.38
# | 에폭 5 |  반복 581 / 1327 | 시간 192[s] | 퍼플렉서티 94.07
# | 에폭 5 |  반복 601 / 1327 | 시간 199[s] | 퍼플렉서티 131.90
# | 에폭 5 |  반복 621 / 1327 | 시간 205[s] | 퍼플렉서티 123.37
# | 에폭 5 |  반복 641 / 1327 | 시간 212[s] | 퍼플렉서티 112.73
# | 에폭 5 |  반복 661 / 1327 | 시간 218[s] | 퍼플렉서티 103.40
# | 에폭 5 |  반복 681 / 1327 | 시간 225[s] | 퍼플렉서티 89.05
# | 에폭 5 |  반복 701 / 1327 | 시간 231[s] | 퍼플렉서티 106.71
# | 에폭 5 |  반복 721 / 1327 | 시간 238[s] | 퍼플렉서티 108.19
# | 에폭 5 |  반복 741 / 1327 | 시간 244[s] | 퍼플렉서티 92.89
# | 에폭 5 |  반복 761 / 1327 | 시간 250[s] | 퍼플렉서티 85.73
# | 에폭 5 |  반복 781 / 1327 | 시간 257[s] | 퍼플렉서티 93.70
# | 에폭 5 |  반복 801 / 1327 | 시간 263[s] | 퍼플렉서티 106.24
# | 에폭 5 |  반복 821 / 1327 | 시간 270[s] | 퍼플렉서티 106.99
# | 에폭 5 |  반복 841 / 1327 | 시간 277[s] | 퍼플렉서티 104.68
# | 에폭 5 |  반복 861 / 1327 | 시간 283[s] | 퍼플렉서티 104.31
# | 에폭 5 |  반복 881 / 1327 | 시간 290[s] | 퍼플렉서티 95.57
# | 에폭 5 |  반복 901 / 1327 | 시간 296[s] | 퍼플렉서티 119.53
# | 에폭 5 |  반복 921 / 1327 | 시간 302[s] | 퍼플렉서티 106.16
# | 에폭 5 |  반복 941 / 1327 | 시간 309[s] | 퍼플렉서티 113.01
# | 에폭 5 |  반복 961 / 1327 | 시간 315[s] | 퍼플렉서티 121.48
# | 에폭 5 |  반복 981 / 1327 | 시간 321[s] | 퍼플렉서티 115.35
# | 에폭 5 |  반복 1001 / 1327 | 시간 328[s] | 퍼플렉서티 98.71
# | 에폭 5 |  반복 1021 / 1327 | 시간 335[s] | 퍼플렉서티 116.89
# | 에폭 5 |  반복 1041 / 1327 | 시간 341[s] | 퍼플렉서티 101.22
# | 에폭 5 |  반복 1061 / 1327 | 시간 348[s] | 퍼플렉서티 95.39
# | 에폭 5 |  반복 1081 / 1327 | 시간 356[s] | 퍼플렉서티 78.21
# | 에폭 5 |  반복 1101 / 1327 | 시간 363[s] | 퍼플렉서티 81.50
# | 에폭 5 |  반복 1121 / 1327 | 시간 369[s] | 퍼플렉서티 112.86
# | 에폭 5 |  반복 1141 / 1327 | 시간 376[s] | 퍼플렉서티 105.40
# | 에폭 5 |  반복 1161 / 1327 | 시간 383[s] | 퍼플렉서티 90.56
# | 에폭 5 |  반복 1181 / 1327 | 시간 390[s] | 퍼플렉서티 99.85
# | 에폭 5 |  반복 1201 / 1327 | 시간 396[s] | 퍼플렉서티 81.72
# | 에폭 5 |  반복 1221 / 1327 | 시간 403[s] | 퍼플렉서티 82.94
# | 에폭 5 |  반복 1241 / 1327 | 시간 409[s] | 퍼플렉서티 98.83
# | 에폭 5 |  반복 1261 / 1327 | 시간 416[s] | 퍼플렉서티 92.96
# | 에폭 5 |  반복 1281 / 1327 | 시간 423[s] | 퍼플렉서티 93.69
# | 에폭 5 |  반복 1301 / 1327 | 시간 429[s] | 퍼플렉서티 119.56
# | 에폭 5 |  반복 1321 / 1327 | 시간 435[s] | 퍼플렉서티 116.60
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  105.08283
# --------------------------------------------------
# | 에폭 6 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 156.93
# | 에폭 6 |  반복 21 / 1327 | 시간 6[s] | 퍼플렉서티 101.29
# | 에폭 6 |  반복 41 / 1327 | 시간 13[s] | 퍼플렉서티 99.28
# | 에폭 6 |  반복 61 / 1327 | 시간 20[s] | 퍼플렉서티 95.22
# | 에폭 6 |  반복 81 / 1327 | 시간 27[s] | 퍼플렉서티 83.71
# | 에폭 6 |  반복 101 / 1327 | 시간 35[s] | 퍼플렉서티 80.22
# | 에폭 6 |  반복 121 / 1327 | 시간 42[s] | 퍼플렉서티 88.78
# | 에폭 6 |  반복 141 / 1327 | 시간 49[s] | 퍼플렉서티 98.21
# | 에폭 6 |  반복 161 / 1327 | 시간 55[s] | 퍼플렉서티 110.69
# | 에폭 6 |  반복 181 / 1327 | 시간 62[s] | 퍼플렉서티 118.98
# | 에폭 6 |  반복 201 / 1327 | 시간 69[s] | 퍼플렉서티 113.65
# | 에폭 6 |  반복 221 / 1327 | 시간 77[s] | 퍼플렉서티 110.29
# | 에폭 6 |  반복 241 / 1327 | 시간 85[s] | 퍼플렉서티 106.32
# | 에폭 6 |  반복 261 / 1327 | 시간 93[s] | 퍼플렉서티 112.86
# | 에폭 6 |  반복 281 / 1327 | 시간 101[s] | 퍼플렉서티 109.10
# | 에폭 6 |  반복 301 / 1327 | 시간 108[s] | 퍼플렉서티 92.38
# | 에폭 6 |  반복 321 / 1327 | 시간 115[s] | 퍼플렉서티 74.08
# | 에폭 6 |  반복 341 / 1327 | 시간 123[s] | 퍼플렉서티 105.46
# | 에폭 6 |  반복 361 / 1327 | 시간 131[s] | 퍼플렉서티 111.78
# | 에폭 6 |  반복 381 / 1327 | 시간 138[s] | 퍼플렉서티 90.93
# | 에폭 6 |  반복 401 / 1327 | 시간 145[s] | 퍼플렉서티 104.32
# | 에폭 6 |  반복 421 / 1327 | 시간 151[s] | 퍼플렉서티 88.64
# | 에폭 6 |  반복 441 / 1327 | 시간 158[s] | 퍼플렉서티 96.44
# | 에폭 6 |  반복 461 / 1327 | 시간 164[s] | 퍼플렉서티 95.86
# | 에폭 6 |  반복 481 / 1327 | 시간 171[s] | 퍼플렉서티 95.12
# | 에폭 6 |  반복 501 / 1327 | 시간 177[s] | 퍼플렉서티 104.54
# | 에폭 6 |  반복 521 / 1327 | 시간 184[s] | 퍼플렉서티 109.48
# | 에폭 6 |  반복 541 / 1327 | 시간 190[s] | 퍼플렉서티 109.77
# | 에폭 6 |  반복 561 / 1327 | 시간 197[s] | 퍼플렉서티 92.50
# | 에폭 6 |  반복 581 / 1327 | 시간 203[s] | 퍼플렉서티 85.64
# | 에폭 6 |  반복 601 / 1327 | 시간 209[s] | 퍼플렉서티 122.33
# | 에폭 6 |  반복 621 / 1327 | 시간 216[s] | 퍼플렉서티 112.92
# | 에폭 6 |  반복 641 / 1327 | 시간 222[s] | 퍼플렉서티 102.96
# | 에폭 6 |  반복 661 / 1327 | 시간 229[s] | 퍼플렉서티 95.63
# | 에폭 6 |  반복 681 / 1327 | 시간 235[s] | 퍼플렉서티 82.38
# | 에폭 6 |  반복 701 / 1327 | 시간 241[s] | 퍼플렉서티 97.54
# | 에폭 6 |  반복 721 / 1327 | 시간 248[s] | 퍼플렉서티 99.87
# | 에폭 6 |  반복 741 / 1327 | 시간 254[s] | 퍼플렉서티 85.86
# | 에폭 6 |  반복 761 / 1327 | 시간 261[s] | 퍼플렉서티 78.91
# | 에폭 6 |  반복 781 / 1327 | 시간 267[s] | 퍼플렉서티 86.41
# | 에폭 6 |  반복 801 / 1327 | 시간 274[s] | 퍼플렉서티 97.69
# | 에폭 6 |  반복 821 / 1327 | 시간 280[s] | 퍼플렉서티 97.25
# | 에폭 6 |  반복 841 / 1327 | 시간 287[s] | 퍼플렉서티 96.44
# | 에폭 6 |  반복 861 / 1327 | 시간 293[s] | 퍼플렉서티 96.22
# | 에폭 6 |  반복 881 / 1327 | 시간 300[s] | 퍼플렉서티 87.36
# | 에폭 6 |  반복 901 / 1327 | 시간 306[s] | 퍼플렉서티 110.41
# | 에폭 6 |  반복 921 / 1327 | 시간 312[s] | 퍼플렉서티 97.49
# | 에폭 6 |  반복 941 / 1327 | 시간 319[s] | 퍼플렉서티 105.42
# | 에폭 6 |  반복 961 / 1327 | 시간 326[s] | 퍼플렉서티 111.76
# | 에폭 6 |  반복 981 / 1327 | 시간 332[s] | 퍼플렉서티 105.76
# | 에폭 6 |  반복 1001 / 1327 | 시간 338[s] | 퍼플렉서티 91.02
# | 에폭 6 |  반복 1021 / 1327 | 시간 345[s] | 퍼플렉서티 108.15
# | 에폭 6 |  반복 1041 / 1327 | 시간 351[s] | 퍼플렉서티 94.38
# | 에폭 6 |  반복 1061 / 1327 | 시간 359[s] | 퍼플렉서티 89.46
# | 에폭 6 |  반복 1081 / 1327 | 시간 365[s] | 퍼플렉서티 71.73
# | 에폭 6 |  반복 1101 / 1327 | 시간 371[s] | 퍼플렉서티 75.30
# | 에폭 6 |  반복 1121 / 1327 | 시간 378[s] | 퍼플렉서티 102.73
# | 에폭 6 |  반복 1141 / 1327 | 시간 384[s] | 퍼플렉서티 98.17
# | 에폭 6 |  반복 1161 / 1327 | 시간 391[s] | 퍼플렉서티 84.21
# | 에폭 6 |  반복 1181 / 1327 | 시간 397[s] | 퍼플렉서티 92.55
# | 에폭 6 |  반복 1201 / 1327 | 시간 404[s] | 퍼플렉서티 76.36
# | 에폭 6 |  반복 1221 / 1327 | 시간 410[s] | 퍼플렉서티 76.69
# | 에폭 6 |  반복 1241 / 1327 | 시간 416[s] | 퍼플렉서티 91.50
# | 에폭 6 |  반복 1261 / 1327 | 시간 423[s] | 퍼플렉서티 87.27
# | 에폭 6 |  반복 1281 / 1327 | 시간 429[s] | 퍼플렉서티 86.64
# | 에폭 6 |  반복 1301 / 1327 | 시간 435[s] | 퍼플렉서티 110.16
# | 에폭 6 |  반복 1321 / 1327 | 시간 442[s] | 퍼플렉서티 107.34
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  100.93644
# --------------------------------------------------
# | 에폭 7 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 151.09
# | 에폭 7 |  반복 21 / 1327 | 시간 6[s] | 퍼플렉서티 93.97
# | 에폭 7 |  반복 41 / 1327 | 시간 13[s] | 퍼플렉서티 92.23
# | 에폭 7 |  반복 61 / 1327 | 시간 19[s] | 퍼플렉서티 89.97
# | 에폭 7 |  반복 81 / 1327 | 시간 25[s] | 퍼플렉서티 77.03
# | 에폭 7 |  반복 101 / 1327 | 시간 32[s] | 퍼플렉서티 74.20
# | 에폭 7 |  반복 121 / 1327 | 시간 39[s] | 퍼플렉서티 82.29
# | 에폭 7 |  반복 141 / 1327 | 시간 45[s] | 퍼플렉서티 89.07
# | 에폭 7 |  반복 161 / 1327 | 시간 52[s] | 퍼플렉서티 103.47
# | 에폭 7 |  반복 181 / 1327 | 시간 58[s] | 퍼플렉서티 109.61
# | 에폭 7 |  반복 201 / 1327 | 시간 65[s] | 퍼플렉서티 107.26
# | 에폭 7 |  반복 221 / 1327 | 시간 71[s] | 퍼플렉서티 102.82
# | 에폭 7 |  반복 241 / 1327 | 시간 78[s] | 퍼플렉서티 98.98
# | 에폭 7 |  반복 261 / 1327 | 시간 84[s] | 퍼플렉서티 104.14
# | 에폭 7 |  반복 281 / 1327 | 시간 91[s] | 퍼플렉서티 100.85
# | 에폭 7 |  반복 301 / 1327 | 시간 98[s] | 퍼플렉서티 85.53
# | 에폭 7 |  반복 321 / 1327 | 시간 105[s] | 퍼플렉서티 68.62
# | 에폭 7 |  반복 341 / 1327 | 시간 111[s] | 퍼플렉서티 97.88
# | 에폭 7 |  반복 361 / 1327 | 시간 118[s] | 퍼플렉서티 103.23
# | 에폭 7 |  반복 381 / 1327 | 시간 125[s] | 퍼플렉서티 86.12
# | 에폭 7 |  반복 401 / 1327 | 시간 132[s] | 퍼플렉서티 97.08
# | 에폭 7 |  반복 421 / 1327 | 시간 139[s] | 퍼플렉서티 84.08
# | 에폭 7 |  반복 441 / 1327 | 시간 146[s] | 퍼플렉서티 88.95
# | 에폭 7 |  반복 461 / 1327 | 시간 152[s] | 퍼플렉서티 88.87
# | 에폭 7 |  반복 481 / 1327 | 시간 159[s] | 퍼플렉서티 88.86
# | 에폭 7 |  반복 501 / 1327 | 시간 166[s] | 퍼플렉서티 98.00
# | 에폭 7 |  반복 521 / 1327 | 시간 173[s] | 퍼플렉서티 102.37
# | 에폭 7 |  반복 541 / 1327 | 시간 180[s] | 퍼플렉서티 102.03
# | 에폭 7 |  반복 561 / 1327 | 시간 186[s] | 퍼플렉서티 85.57
# | 에폭 7 |  반복 581 / 1327 | 시간 193[s] | 퍼플렉서티 80.86
# | 에폭 7 |  반복 601 / 1327 | 시간 200[s] | 퍼플렉서티 112.79
# | 에폭 7 |  반복 621 / 1327 | 시간 206[s] | 퍼플렉서티 105.53
# | 에폭 7 |  반복 641 / 1327 | 시간 213[s] | 퍼플렉서티 96.34
# | 에폭 7 |  반복 661 / 1327 | 시간 220[s] | 퍼플렉서티 88.37
# | 에폭 7 |  반복 681 / 1327 | 시간 227[s] | 퍼플렉서티 78.05
# | 에폭 7 |  반복 701 / 1327 | 시간 233[s] | 퍼플렉서티 90.38
# | 에폭 7 |  반복 721 / 1327 | 시간 240[s] | 퍼플렉서티 92.02
# | 에폭 7 |  반복 741 / 1327 | 시간 247[s] | 퍼플렉서티 80.01
# | 에폭 7 |  반복 761 / 1327 | 시간 254[s] | 퍼플렉서티 73.63
# | 에폭 7 |  반복 781 / 1327 | 시간 260[s] | 퍼플렉서티 81.31
# | 에폭 7 |  반복 801 / 1327 | 시간 267[s] | 퍼플렉서티 91.95
# | 에폭 7 |  반복 821 / 1327 | 시간 274[s] | 퍼플렉서티 93.02
# | 에폭 7 |  반복 841 / 1327 | 시간 280[s] | 퍼플렉서티 91.06
# | 에폭 7 |  반복 861 / 1327 | 시간 287[s] | 퍼플렉서티 90.41
# | 에폭 7 |  반복 881 / 1327 | 시간 293[s] | 퍼플렉서티 83.96
# | 에폭 7 |  반복 901 / 1327 | 시간 300[s] | 퍼플렉서티 102.77
# | 에폭 7 |  반복 921 / 1327 | 시간 306[s] | 퍼플렉서티 92.81
# | 에폭 7 |  반복 941 / 1327 | 시간 313[s] | 퍼플렉서티 96.78
# | 에폭 7 |  반복 961 / 1327 | 시간 319[s] | 퍼플렉서티 106.69
# | 에폭 7 |  반복 981 / 1327 | 시간 325[s] | 퍼플렉서티 100.81
# | 에폭 7 |  반복 1001 / 1327 | 시간 332[s] | 퍼플렉서티 85.77
# | 에폭 7 |  반복 1021 / 1327 | 시간 338[s] | 퍼플렉서티 102.33
# | 에폭 7 |  반복 1041 / 1327 | 시간 345[s] | 퍼플렉서티 89.01
# | 에폭 7 |  반복 1061 / 1327 | 시간 351[s] | 퍼플렉서티 83.48
# | 에폭 7 |  반복 1081 / 1327 | 시간 358[s] | 퍼플렉서티 68.96
# | 에폭 7 |  반복 1101 / 1327 | 시간 364[s] | 퍼플렉서티 71.04
# | 에폭 7 |  반복 1121 / 1327 | 시간 370[s] | 퍼플렉서티 96.27
# | 에폭 7 |  반복 1141 / 1327 | 시간 377[s] | 퍼플렉서티 92.04
# | 에폭 7 |  반복 1161 / 1327 | 시간 383[s] | 퍼플렉서티 77.95
# | 에폭 7 |  반복 1181 / 1327 | 시간 389[s] | 퍼플렉서티 87.77
# | 에폭 7 |  반복 1201 / 1327 | 시간 396[s] | 퍼플렉서티 72.25
# | 에폭 7 |  반복 1221 / 1327 | 시간 402[s] | 퍼플렉서티 71.45
# | 에폭 7 |  반복 1241 / 1327 | 시간 409[s] | 퍼플렉서티 85.51
# | 에폭 7 |  반복 1261 / 1327 | 시간 415[s] | 퍼플렉서티 82.09
# | 에폭 7 |  반복 1281 / 1327 | 시간 421[s] | 퍼플렉서티 81.95
# | 에폭 7 |  반복 1301 / 1327 | 시간 428[s] | 퍼플렉서티 105.20
# | 에폭 7 |  반복 1321 / 1327 | 시간 434[s] | 퍼플렉서티 101.88
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  96.917694
# --------------------------------------------------
# | 에폭 8 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 145.76
# | 에폭 8 |  반복 21 / 1327 | 시간 6[s] | 퍼플렉서티 89.85
# | 에폭 8 |  반복 41 / 1327 | 시간 13[s] | 퍼플렉서티 86.62
# | 에폭 8 |  반복 61 / 1327 | 시간 19[s] | 퍼플렉서티 83.83
# | 에폭 8 |  반복 81 / 1327 | 시간 26[s] | 퍼플렉서티 72.61
# | 에폭 8 |  반복 101 / 1327 | 시간 32[s] | 퍼플렉서티 70.30
# | 에폭 8 |  반복 121 / 1327 | 시간 38[s] | 퍼플렉서티 78.15
# | 에폭 8 |  반복 141 / 1327 | 시간 45[s] | 퍼플렉서티 84.04
# | 에폭 8 |  반복 161 / 1327 | 시간 52[s] | 퍼플렉서티 96.93
# | 에폭 8 |  반복 181 / 1327 | 시간 58[s] | 퍼플렉서티 103.90
# | 에폭 8 |  반복 201 / 1327 | 시간 65[s] | 퍼플렉서티 100.62
# | 에폭 8 |  반복 221 / 1327 | 시간 72[s] | 퍼플렉서티 99.24
# | 에폭 8 |  반복 241 / 1327 | 시간 79[s] | 퍼플렉서티 91.52
# | 에폭 8 |  반복 261 / 1327 | 시간 86[s] | 퍼플렉서티 98.93
# | 에폭 8 |  반복 281 / 1327 | 시간 92[s] | 퍼플렉서티 96.17
# | 에폭 8 |  반복 301 / 1327 | 시간 99[s] | 퍼플렉서티 80.84
# | 에폭 8 |  반복 321 / 1327 | 시간 105[s] | 퍼플렉서티 64.58
# | 에폭 8 |  반복 341 / 1327 | 시간 112[s] | 퍼플렉서티 93.81
# | 에폭 8 |  반복 361 / 1327 | 시간 118[s] | 퍼플렉서티 96.72
# | 에폭 8 |  반복 381 / 1327 | 시간 124[s] | 퍼플렉서티 80.27
# | 에폭 8 |  반복 401 / 1327 | 시간 131[s] | 퍼플렉서티 91.10
# | 에폭 8 |  반복 421 / 1327 | 시간 137[s] | 퍼플렉서티 78.29
# | 에폭 8 |  반복 441 / 1327 | 시간 144[s] | 퍼플렉서티 83.87
# | 에폭 8 |  반복 461 / 1327 | 시간 151[s] | 퍼플렉서티 83.93
# | 에폭 8 |  반복 481 / 1327 | 시간 159[s] | 퍼플렉서티 83.88
# | 에폭 8 |  반복 501 / 1327 | 시간 166[s] | 퍼플렉서티 93.96
# | 에폭 8 |  반복 521 / 1327 | 시간 174[s] | 퍼플렉서티 95.01
# | 에폭 8 |  반복 541 / 1327 | 시간 181[s] | 퍼플렉서티 96.97
# | 에폭 8 |  반복 561 / 1327 | 시간 188[s] | 퍼플렉서티 81.46
# | 에폭 8 |  반복 581 / 1327 | 시간 195[s] | 퍼플렉서티 75.57
# | 에폭 8 |  반복 601 / 1327 | 시간 201[s] | 퍼플렉서티 105.99
# | 에폭 8 |  반복 621 / 1327 | 시간 207[s] | 퍼플렉서티 100.13
# | 에폭 8 |  반복 641 / 1327 | 시간 214[s] | 퍼플렉서티 89.87
# | 에폭 8 |  반복 661 / 1327 | 시간 220[s] | 퍼플렉서티 83.36
# | 에폭 8 |  반복 681 / 1327 | 시간 227[s] | 퍼플렉서티 73.13
# | 에폭 8 |  반복 701 / 1327 | 시간 233[s] | 퍼플렉서티 86.55
# | 에폭 8 |  반복 721 / 1327 | 시간 240[s] | 퍼플렉서티 87.52
# | 에폭 8 |  반복 741 / 1327 | 시간 247[s] | 퍼플렉서티 75.68
# | 에폭 8 |  반복 761 / 1327 | 시간 254[s] | 퍼플렉서티 69.58
# | 에폭 8 |  반복 781 / 1327 | 시간 260[s] | 퍼플렉서티 76.71
# | 에폭 8 |  반복 801 / 1327 | 시간 267[s] | 퍼플렉서티 86.26
# | 에폭 8 |  반복 821 / 1327 | 시간 273[s] | 퍼플렉서티 86.62
# | 에폭 8 |  반복 841 / 1327 | 시간 280[s] | 퍼플렉서티 86.09
# | 에폭 8 |  반복 861 / 1327 | 시간 286[s] | 퍼플렉서티 86.57
# | 에폭 8 |  반복 881 / 1327 | 시간 292[s] | 퍼플렉서티 78.70
# | 에폭 8 |  반복 901 / 1327 | 시간 299[s] | 퍼플렉서티 98.68
# | 에폭 8 |  반복 921 / 1327 | 시간 306[s] | 퍼플렉서티 88.09
# | 에폭 8 |  반복 941 / 1327 | 시간 312[s] | 퍼플렉서티 93.32
# | 에폭 8 |  반복 961 / 1327 | 시간 319[s] | 퍼플렉서티 98.98
# | 에폭 8 |  반복 981 / 1327 | 시간 326[s] | 퍼플렉서티 94.21
# | 에폭 8 |  반복 1001 / 1327 | 시간 333[s] | 퍼플렉서티 81.50
# | 에폭 8 |  반복 1021 / 1327 | 시간 340[s] | 퍼플렉서티 96.87
# | 에폭 8 |  반복 1041 / 1327 | 시간 346[s] | 퍼플렉서티 82.69
# | 에폭 8 |  반복 1061 / 1327 | 시간 353[s] | 퍼플렉서티 78.72
# | 에폭 8 |  반복 1081 / 1327 | 시간 360[s] | 퍼플렉서티 64.89
# | 에폭 8 |  반복 1101 / 1327 | 시간 366[s] | 퍼플렉서티 66.18
# | 에폭 8 |  반복 1121 / 1327 | 시간 372[s] | 퍼플렉서티 91.58
# | 에폭 8 |  반복 1141 / 1327 | 시간 379[s] | 퍼플렉서티 89.37
# | 에폭 8 |  반복 1161 / 1327 | 시간 385[s] | 퍼플렉서티 73.96
# | 에폭 8 |  반복 1181 / 1327 | 시간 392[s] | 퍼플렉서티 83.69
# | 에폭 8 |  반복 1201 / 1327 | 시간 398[s] | 퍼플렉서티 67.89
# | 에폭 8 |  반복 1221 / 1327 | 시간 404[s] | 퍼플렉서티 67.57
# | 에폭 8 |  반복 1241 / 1327 | 시간 411[s] | 퍼플렉서티 81.43
# | 에폭 8 |  반복 1261 / 1327 | 시간 417[s] | 퍼플렉서티 77.51
# | 에폭 8 |  반복 1281 / 1327 | 시간 424[s] | 퍼플렉서티 77.83
# | 에폭 8 |  반복 1301 / 1327 | 시간 430[s] | 퍼플렉서티 98.73
# | 에폭 8 |  반복 1321 / 1327 | 시간 437[s] | 퍼플렉서티 96.96
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  94.486565
# --------------------------------------------------
# | 에폭 9 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 137.62
# | 에폭 9 |  반복 21 / 1327 | 시간 6[s] | 퍼플렉서티 83.62
# | 에폭 9 |  반복 41 / 1327 | 시간 13[s] | 퍼플렉서티 82.53
# | 에폭 9 |  반복 61 / 1327 | 시간 19[s] | 퍼플렉서티 79.66
# | 에폭 9 |  반복 81 / 1327 | 시간 26[s] | 퍼플렉서티 69.10
# | 에폭 9 |  반복 101 / 1327 | 시간 32[s] | 퍼플렉서티 67.34
# | 에폭 9 |  반복 121 / 1327 | 시간 39[s] | 퍼플렉서티 74.43
# | 에폭 9 |  반복 141 / 1327 | 시간 46[s] | 퍼플렉서티 80.53
# | 에폭 9 |  반복 161 / 1327 | 시간 53[s] | 퍼플렉서티 92.40
# | 에폭 9 |  반복 181 / 1327 | 시간 59[s] | 퍼플렉서티 98.28
# | 에폭 9 |  반복 201 / 1327 | 시간 66[s] | 퍼플렉서티 95.61
# | 에폭 9 |  반복 221 / 1327 | 시간 73[s] | 퍼플렉서티 92.99
# | 에폭 9 |  반복 241 / 1327 | 시간 80[s] | 퍼플렉서티 88.49
# | 에폭 9 |  반복 261 / 1327 | 시간 86[s] | 퍼플렉서티 92.83
# | 에폭 9 |  반복 281 / 1327 | 시간 93[s] | 퍼플렉서티 92.25
# | 에폭 9 |  반복 301 / 1327 | 시간 99[s] | 퍼플렉서티 76.08
# | 에폭 9 |  반복 321 / 1327 | 시간 106[s] | 퍼플렉서티 61.29
# | 에폭 9 |  반복 341 / 1327 | 시간 113[s] | 퍼플렉서티 88.35
# | 에폭 9 |  반복 361 / 1327 | 시간 119[s] | 퍼플렉서티 93.01
# | 에폭 9 |  반복 381 / 1327 | 시간 125[s] | 퍼플렉서티 75.83
# | 에폭 9 |  반복 401 / 1327 | 시간 132[s] | 퍼플렉서티 86.41
# | 에폭 9 |  반복 421 / 1327 | 시간 138[s] | 퍼플렉서티 75.14
# | 에폭 9 |  반복 441 / 1327 | 시간 145[s] | 퍼플렉서티 79.94
# | 에폭 9 |  반복 461 / 1327 | 시간 151[s] | 퍼플렉서티 80.82
# | 에폭 9 |  반복 481 / 1327 | 시간 157[s] | 퍼플렉서티 79.71
# | 에폭 9 |  반복 501 / 1327 | 시간 164[s] | 퍼플렉서티 87.56
# | 에폭 9 |  반복 521 / 1327 | 시간 170[s] | 퍼플렉서티 89.91
# | 에폭 9 |  반복 541 / 1327 | 시간 176[s] | 퍼플렉서티 90.30
# | 에폭 9 |  반복 561 / 1327 | 시간 183[s] | 퍼플렉서티 78.54
# | 에폭 9 |  반복 581 / 1327 | 시간 189[s] | 퍼플렉서티 72.22
# | 에폭 9 |  반복 601 / 1327 | 시간 196[s] | 퍼플렉서티 101.69
# | 에폭 9 |  반복 621 / 1327 | 시간 202[s] | 퍼플렉서티 94.63
# | 에폭 9 |  반복 641 / 1327 | 시간 208[s] | 퍼플렉서티 86.62
# | 에폭 9 |  반복 661 / 1327 | 시간 215[s] | 퍼플렉서티 80.16
# | 에폭 9 |  반복 681 / 1327 | 시간 221[s] | 퍼플렉서티 69.46
# | 에폭 9 |  반복 701 / 1327 | 시간 228[s] | 퍼플렉서티 82.18
# | 에폭 9 |  반복 721 / 1327 | 시간 234[s] | 퍼플렉서티 83.21
# | 에폭 9 |  반복 741 / 1327 | 시간 240[s] | 퍼플렉서티 73.24
# | 에폭 9 |  반복 761 / 1327 | 시간 247[s] | 퍼플렉서티 66.13
# | 에폭 9 |  반복 781 / 1327 | 시간 253[s] | 퍼플렉서티 73.35
# | 에폭 9 |  반복 801 / 1327 | 시간 260[s] | 퍼플렉서티 84.32
# | 에폭 9 |  반복 821 / 1327 | 시간 266[s] | 퍼플렉서티 83.33
# | 에폭 9 |  반복 841 / 1327 | 시간 272[s] | 퍼플렉서티 82.70
# | 에폭 9 |  반복 861 / 1327 | 시간 279[s] | 퍼플렉서티 81.70
# | 에폭 9 |  반복 881 / 1327 | 시간 285[s] | 퍼플렉서티 74.42
# | 에폭 9 |  반복 901 / 1327 | 시간 291[s] | 퍼플렉서티 94.55
# | 에폭 9 |  반복 921 / 1327 | 시간 298[s] | 퍼플렉서티 83.32
# | 에폭 9 |  반복 941 / 1327 | 시간 304[s] | 퍼플렉서티 89.65
# | 에폭 9 |  반복 961 / 1327 | 시간 310[s] | 퍼플렉서티 95.33
# | 에폭 9 |  반복 981 / 1327 | 시간 317[s] | 퍼플렉서티 91.44
# | 에폭 9 |  반복 1001 / 1327 | 시간 323[s] | 퍼플렉서티 77.62
# | 에폭 9 |  반복 1021 / 1327 | 시간 330[s] | 퍼플렉서티 92.15
# | 에폭 9 |  반복 1041 / 1327 | 시간 336[s] | 퍼플렉서티 80.39
# | 에폭 9 |  반복 1061 / 1327 | 시간 342[s] | 퍼플렉서티 75.29
# | 에폭 9 |  반복 1081 / 1327 | 시간 349[s] | 퍼플렉서티 62.39
# | 에폭 9 |  반복 1101 / 1327 | 시간 355[s] | 퍼플렉서티 63.68
# | 에폭 9 |  반복 1121 / 1327 | 시간 361[s] | 퍼플렉서티 89.07
# | 에폭 9 |  반복 1141 / 1327 | 시간 368[s] | 퍼플렉서티 83.66
# | 에폭 9 |  반복 1161 / 1327 | 시간 374[s] | 퍼플렉서티 70.04
# | 에폭 9 |  반복 1181 / 1327 | 시간 381[s] | 퍼플렉서티 78.58
# | 에폭 9 |  반복 1201 / 1327 | 시간 387[s] | 퍼플렉서티 64.69
# | 에폭 9 |  반복 1221 / 1327 | 시간 393[s] | 퍼플렉서티 66.24
# | 에폭 9 |  반복 1241 / 1327 | 시간 400[s] | 퍼플렉서티 78.59
# | 에폭 9 |  반복 1261 / 1327 | 시간 406[s] | 퍼플렉서티 74.31
# | 에폭 9 |  반복 1281 / 1327 | 시간 413[s] | 퍼플렉서티 74.67
# | 에폭 9 |  반복 1301 / 1327 | 시간 419[s] | 퍼플렉서티 93.34
# | 에폭 9 |  반복 1321 / 1327 | 시간 426[s] | 퍼플렉서티 91.34
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  92.41519
# --------------------------------------------------
# | 에폭 10 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 129.15
# | 에폭 10 |  반복 21 / 1327 | 시간 6[s] | 퍼플렉서티 81.03
# | 에폭 10 |  반복 41 / 1327 | 시간 13[s] | 퍼플렉서티 78.79
# | 에폭 10 |  반복 61 / 1327 | 시간 19[s] | 퍼플렉서티 77.20
# | 에폭 10 |  반복 81 / 1327 | 시간 26[s] | 퍼플렉서티 65.62
# | 에폭 10 |  반복 101 / 1327 | 시간 32[s] | 퍼플렉서티 64.80
# | 에폭 10 |  반복 121 / 1327 | 시간 38[s] | 퍼플렉서티 71.29
# | 에폭 10 |  반복 141 / 1327 | 시간 45[s] | 퍼플렉서티 76.52
# | 에폭 10 |  반복 161 / 1327 | 시간 51[s] | 퍼플렉서티 88.23
# | 에폭 10 |  반복 181 / 1327 | 시간 58[s] | 퍼플렉서티 95.04
# | 에폭 10 |  반복 201 / 1327 | 시간 64[s] | 퍼플렉서티 93.01
# | 에폭 10 |  반복 221 / 1327 | 시간 70[s] | 퍼플렉서티 90.07
# | 에폭 10 |  반복 241 / 1327 | 시간 77[s] | 퍼플렉서티 84.68
# | 에폭 10 |  반복 261 / 1327 | 시간 83[s] | 퍼플렉서티 89.97
# | 에폭 10 |  반복 281 / 1327 | 시간 89[s] | 퍼플렉서티 86.19
# | 에폭 10 |  반복 301 / 1327 | 시간 96[s] | 퍼플렉서티 73.47
# | 에폭 10 |  반복 321 / 1327 | 시간 102[s] | 퍼플렉서티 58.71
# | 에폭 10 |  반복 341 / 1327 | 시간 108[s] | 퍼플렉서티 84.36
# | 에폭 10 |  반복 361 / 1327 | 시간 115[s] | 퍼플렉서티 88.13
# | 에폭 10 |  반복 381 / 1327 | 시간 121[s] | 퍼플렉서티 73.06
# | 에폭 10 |  반복 401 / 1327 | 시간 128[s] | 퍼플렉서티 83.46
# | 에폭 10 |  반복 421 / 1327 | 시간 134[s] | 퍼플렉서티 71.67
# | 에폭 10 |  반복 441 / 1327 | 시간 140[s] | 퍼플렉서티 77.16
# | 에폭 10 |  반복 461 / 1327 | 시간 147[s] | 퍼플렉서티 77.28
# | 에폭 10 |  반복 481 / 1327 | 시간 153[s] | 퍼플렉서티 77.37
# | 에폭 10 |  반복 501 / 1327 | 시간 160[s] | 퍼플렉서티 85.64
# | 에폭 10 |  반복 521 / 1327 | 시간 167[s] | 퍼플렉서티 87.32
# | 에폭 10 |  반복 541 / 1327 | 시간 173[s] | 퍼플렉서티 87.68
# | 에폭 10 |  반복 561 / 1327 | 시간 180[s] | 퍼플렉서티 74.28
# | 에폭 10 |  반복 581 / 1327 | 시간 186[s] | 퍼플렉서티 69.64
# | 에폭 10 |  반복 601 / 1327 | 시간 193[s] | 퍼플렉서티 97.17
# | 에폭 10 |  반복 621 / 1327 | 시간 199[s] | 퍼플렉서티 90.38
# | 에폭 10 |  반복 641 / 1327 | 시간 205[s] | 퍼플렉서티 82.85
# | 에폭 10 |  반복 661 / 1327 | 시간 212[s] | 퍼플렉서티 75.42
# | 에폭 10 |  반복 681 / 1327 | 시간 218[s] | 퍼플렉서티 66.66
# | 에폭 10 |  반복 701 / 1327 | 시간 225[s] | 퍼플렉서티 79.26
# | 에폭 10 |  반복 721 / 1327 | 시간 231[s] | 퍼플렉서티 80.29
# | 에폭 10 |  반복 741 / 1327 | 시간 238[s] | 퍼플렉서티 70.07
# | 에폭 10 |  반복 761 / 1327 | 시간 244[s] | 퍼플렉서티 64.01
# | 에폭 10 |  반복 781 / 1327 | 시간 250[s] | 퍼플렉서티 70.53
# | 에폭 10 |  반복 801 / 1327 | 시간 257[s] | 퍼플렉서티 79.74
# | 에폭 10 |  반복 821 / 1327 | 시간 263[s] | 퍼플렉서티 79.21
# | 에폭 10 |  반복 841 / 1327 | 시간 271[s] | 퍼플렉서티 79.25
# | 에폭 10 |  반복 861 / 1327 | 시간 278[s] | 퍼플렉서티 79.32
# | 에폭 10 |  반복 881 / 1327 | 시간 287[s] | 퍼플렉서티 72.81
# | 에폭 10 |  반복 901 / 1327 | 시간 295[s] | 퍼플렉서티 91.17
# | 에폭 10 |  반복 921 / 1327 | 시간 302[s] | 퍼플렉서티 80.75
# | 에폭 10 |  반복 941 / 1327 | 시간 312[s] | 퍼플렉서티 87.42
# | 에폭 10 |  반복 961 / 1327 | 시간 319[s] | 퍼플렉서티 91.85
# | 에폭 10 |  반복 981 / 1327 | 시간 325[s] | 퍼플렉서티 88.90
# | 에폭 10 |  반복 1001 / 1327 | 시간 331[s] | 퍼플렉서티 75.67
# | 에폭 10 |  반복 1021 / 1327 | 시간 338[s] | 퍼플렉서티 87.76
# | 에폭 10 |  반복 1041 / 1327 | 시간 345[s] | 퍼플렉서티 76.44
# | 에폭 10 |  반복 1061 / 1327 | 시간 351[s] | 퍼플렉서티 73.42
# | 에폭 10 |  반복 1081 / 1327 | 시간 358[s] | 퍼플렉서티 60.29
# | 에폭 10 |  반복 1101 / 1327 | 시간 364[s] | 퍼플렉서티 60.61
# | 에폭 10 |  반복 1121 / 1327 | 시간 371[s] | 퍼플렉서티 83.86
# | 에폭 10 |  반복 1141 / 1327 | 시간 378[s] | 퍼플렉서티 80.43
# | 에폭 10 |  반복 1161 / 1327 | 시간 385[s] | 퍼플렉서티 67.87
# | 에폭 10 |  반복 1181 / 1327 | 시간 392[s] | 퍼플렉서티 75.69
# | 에폭 10 |  반복 1201 / 1327 | 시간 399[s] | 퍼플렉서티 63.06
# | 에폭 10 |  반복 1221 / 1327 | 시간 406[s] | 퍼플렉서티 62.53
# | 에폭 10 |  반복 1241 / 1327 | 시간 413[s] | 퍼플렉서티 76.52
# | 에폭 10 |  반복 1261 / 1327 | 시간 420[s] | 퍼플렉서티 70.97
# | 에폭 10 |  반복 1281 / 1327 | 시간 427[s] | 퍼플렉서티 71.24
# | 에폭 10 |  반복 1301 / 1327 | 시간 434[s] | 퍼플렉서티 91.12
# | 에폭 10 |  반복 1321 / 1327 | 시간 440[s] | 퍼플렉서티 88.62
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  91.448296
# --------------------------------------------------
# | 에폭 11 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 133.89
# | 에폭 11 |  반복 21 / 1327 | 시간 6[s] | 퍼플렉서티 77.94
# | 에폭 11 |  반복 41 / 1327 | 시간 13[s] | 퍼플렉서티 76.12
# | 에폭 11 |  반복 61 / 1327 | 시간 19[s] | 퍼플렉서티 75.28
# | 에폭 11 |  반복 81 / 1327 | 시간 26[s] | 퍼플렉서티 63.24
# | 에폭 11 |  반복 101 / 1327 | 시간 32[s] | 퍼플렉서티 62.36
# | 에폭 11 |  반복 121 / 1327 | 시간 39[s] | 퍼플렉서티 67.65
# | 에폭 11 |  반복 141 / 1327 | 시간 45[s] | 퍼플렉서티 73.33
# | 에폭 11 |  반복 161 / 1327 | 시간 52[s] | 퍼플렉서티 86.25
# | 에폭 11 |  반복 181 / 1327 | 시간 58[s] | 퍼플렉서티 92.15
# | 에폭 11 |  반복 201 / 1327 | 시간 65[s] | 퍼플렉서티 89.44
# | 에폭 11 |  반복 221 / 1327 | 시간 71[s] | 퍼플렉서티 85.27
# | 에폭 11 |  반복 241 / 1327 | 시간 78[s] | 퍼플렉서티 81.45
# | 에폭 11 |  반복 261 / 1327 | 시간 84[s] | 퍼플렉서티 85.33
# | 에폭 11 |  반복 281 / 1327 | 시간 91[s] | 퍼플렉서티 83.07
# | 에폭 11 |  반복 301 / 1327 | 시간 97[s] | 퍼플렉서티 69.97
# | 에폭 11 |  반복 321 / 1327 | 시간 104[s] | 퍼플렉서티 57.28
# | 에폭 11 |  반복 341 / 1327 | 시간 110[s] | 퍼플렉서티 81.08
# | 에폭 11 |  반복 361 / 1327 | 시간 117[s] | 퍼플렉서티 84.53
# | 에폭 11 |  반복 381 / 1327 | 시간 123[s] | 퍼플렉서티 70.31
# | 에폭 11 |  반복 401 / 1327 | 시간 130[s] | 퍼플렉서티 80.19
# | 에폭 11 |  반복 421 / 1327 | 시간 136[s] | 퍼플렉서티 69.37
# | 에폭 11 |  반복 441 / 1327 | 시간 142[s] | 퍼플렉서티 73.15
# | 에폭 11 |  반복 461 / 1327 | 시간 149[s] | 퍼플렉서티 72.82
# | 에폭 11 |  반복 481 / 1327 | 시간 155[s] | 퍼플렉서티 74.95
# | 에폭 11 |  반복 501 / 1327 | 시간 162[s] | 퍼플렉서티 81.44
# | 에폭 11 |  반복 521 / 1327 | 시간 168[s] | 퍼플렉서티 84.45
# | 에폭 11 |  반복 541 / 1327 | 시간 175[s] | 퍼플렉서티 85.29
# | 에폭 11 |  반복 561 / 1327 | 시간 181[s] | 퍼플렉서티 71.15
# | 에폭 11 |  반복 581 / 1327 | 시간 188[s] | 퍼플렉서티 66.18
# | 에폭 11 |  반복 601 / 1327 | 시간 194[s] | 퍼플렉서티 95.34
# | 에폭 11 |  반복 621 / 1327 | 시간 201[s] | 퍼플렉서티 86.72
# | 에폭 11 |  반복 641 / 1327 | 시간 207[s] | 퍼플렉서티 79.62
# | 에폭 11 |  반복 661 / 1327 | 시간 214[s] | 퍼플렉서티 73.80
# | 에폭 11 |  반복 681 / 1327 | 시간 220[s] | 퍼플렉서티 64.20
# | 에폭 11 |  반복 701 / 1327 | 시간 227[s] | 퍼플렉서티 77.65
# | 에폭 11 |  반복 721 / 1327 | 시간 233[s] | 퍼플렉서티 77.12
# | 에폭 11 |  반복 741 / 1327 | 시간 240[s] | 퍼플렉서티 66.90
# | 에폭 11 |  반복 761 / 1327 | 시간 246[s] | 퍼플렉서티 62.30
# | 에폭 11 |  반복 781 / 1327 | 시간 252[s] | 퍼플렉서티 68.16
# | 에폭 11 |  반복 801 / 1327 | 시간 259[s] | 퍼플렉서티 76.48
# | 에폭 11 |  반복 821 / 1327 | 시간 265[s] | 퍼플렉서티 76.48
# | 에폭 11 |  반복 841 / 1327 | 시간 272[s] | 퍼플렉서티 76.24
# | 에폭 11 |  반복 861 / 1327 | 시간 278[s] | 퍼플렉서티 75.45
# | 에폭 11 |  반복 881 / 1327 | 시간 285[s] | 퍼플렉서티 69.42
# | 에폭 11 |  반복 901 / 1327 | 시간 291[s] | 퍼플렉서티 89.75
# | 에폭 11 |  반복 921 / 1327 | 시간 298[s] | 퍼플렉서티 78.12
# | 에폭 11 |  반복 941 / 1327 | 시간 304[s] | 퍼플렉서티 83.89
# | 에폭 11 |  반복 961 / 1327 | 시간 310[s] | 퍼플렉서티 89.07
# | 에폭 11 |  반복 981 / 1327 | 시간 317[s] | 퍼플렉서티 84.88
# | 에폭 11 |  반복 1001 / 1327 | 시간 323[s] | 퍼플렉서티 73.09
# | 에폭 11 |  반복 1021 / 1327 | 시간 330[s] | 퍼플렉서티 84.79
# | 에폭 11 |  반복 1041 / 1327 | 시간 336[s] | 퍼플렉서티 74.18
# | 에폭 11 |  반복 1061 / 1327 | 시간 343[s] | 퍼플렉서티 71.12
# | 에폭 11 |  반복 1081 / 1327 | 시간 349[s] | 퍼플렉서티 57.78
# | 에폭 11 |  반복 1101 / 1327 | 시간 355[s] | 퍼플렉서티 59.49
# | 에폭 11 |  반복 1121 / 1327 | 시간 362[s] | 퍼플렉서티 81.44
# | 에폭 11 |  반복 1141 / 1327 | 시간 368[s] | 퍼플렉서티 79.17
# | 에폭 11 |  반복 1161 / 1327 | 시간 375[s] | 퍼플렉서티 64.60
# | 에폭 11 |  반복 1181 / 1327 | 시간 381[s] | 퍼플렉서티 73.46
# | 에폭 11 |  반복 1201 / 1327 | 시간 388[s] | 퍼플렉서티 61.05
# | 에폭 11 |  반복 1221 / 1327 | 시간 394[s] | 퍼플렉서티 60.59
# | 에폭 11 |  반복 1241 / 1327 | 시간 400[s] | 퍼플렉서티 73.14
# | 에폭 11 |  반복 1261 / 1327 | 시간 407[s] | 퍼플렉서티 69.84
# | 에폭 11 |  반복 1281 / 1327 | 시간 413[s] | 퍼플렉서티 69.21
# | 에폭 11 |  반복 1301 / 1327 | 시간 420[s] | 퍼플렉서티 89.23
# | 에폭 11 |  반복 1321 / 1327 | 시간 426[s] | 퍼플렉서티 85.84
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  90.240524
# --------------------------------------------------
# | 에폭 12 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 123.83
# | 에폭 12 |  반복 21 / 1327 | 시간 6[s] | 퍼플렉서티 74.50
# | 에폭 12 |  반복 41 / 1327 | 시간 13[s] | 퍼플렉서티 73.36
# | 에폭 12 |  반복 61 / 1327 | 시간 19[s] | 퍼플렉서티 71.15
# | 에폭 12 |  반복 81 / 1327 | 시간 26[s] | 퍼플렉서티 61.68
# | 에폭 12 |  반복 101 / 1327 | 시간 32[s] | 퍼플렉서티 60.55
# | 에폭 12 |  반복 121 / 1327 | 시간 38[s] | 퍼플렉서티 66.09
# | 에폭 12 |  반복 141 / 1327 | 시간 45[s] | 퍼플렉서티 71.21
# | 에폭 12 |  반복 161 / 1327 | 시간 51[s] | 퍼플렉서티 83.71
# | 에폭 12 |  반복 181 / 1327 | 시간 58[s] | 퍼플렉서티 88.44
# | 에폭 12 |  반복 201 / 1327 | 시간 64[s] | 퍼플렉서티 87.97
# | 에폭 12 |  반복 221 / 1327 | 시간 71[s] | 퍼플렉서티 82.74
# | 에폭 12 |  반복 241 / 1327 | 시간 77[s] | 퍼플렉서티 79.03
# | 에폭 12 |  반복 261 / 1327 | 시간 84[s] | 퍼플렉서티 84.51
# | 에폭 12 |  반복 281 / 1327 | 시간 90[s] | 퍼플렉서티 82.34
# | 에폭 12 |  반복 301 / 1327 | 시간 96[s] | 퍼플렉서티 68.16
# | 에폭 12 |  반복 321 / 1327 | 시간 103[s] | 퍼플렉서티 55.80
# | 에폭 12 |  반복 341 / 1327 | 시간 109[s] | 퍼플렉서티 77.49
# | 에폭 12 |  반복 361 / 1327 | 시간 116[s] | 퍼플렉서티 82.27
# | 에폭 12 |  반복 381 / 1327 | 시간 122[s] | 퍼플렉서티 68.29
# | 에폭 12 |  반복 401 / 1327 | 시간 129[s] | 퍼플렉서티 76.85
# | 에폭 12 |  반복 421 / 1327 | 시간 135[s] | 퍼플렉서티 66.46
# | 에폭 12 |  반복 441 / 1327 | 시간 141[s] | 퍼플렉서티 70.20
# | 에폭 12 |  반복 461 / 1327 | 시간 148[s] | 퍼플렉서티 71.77
# | 에폭 12 |  반복 481 / 1327 | 시간 154[s] | 퍼플렉서티 72.42
# | 에폭 12 |  반복 501 / 1327 | 시간 161[s] | 퍼플렉서티 78.92
# | 에폭 12 |  반복 521 / 1327 | 시간 167[s] | 퍼플렉서티 81.92
# | 에폭 12 |  반복 541 / 1327 | 시간 174[s] | 퍼플렉서티 80.39
# | 에폭 12 |  반복 561 / 1327 | 시간 180[s] | 퍼플렉서티 69.30
# | 에폭 12 |  반복 581 / 1327 | 시간 187[s] | 퍼플렉서티 63.64
# | 에폭 12 |  반복 601 / 1327 | 시간 193[s] | 퍼플렉서티 91.04
# | 에폭 12 |  반복 621 / 1327 | 시간 200[s] | 퍼플렉서티 84.39
# | 에폭 12 |  반복 641 / 1327 | 시간 206[s] | 퍼플렉서티 78.06
# | 에폭 12 |  반복 661 / 1327 | 시간 212[s] | 퍼플렉서티 72.44
# | 에폭 12 |  반복 681 / 1327 | 시간 219[s] | 퍼플렉서티 62.65
# | 에폭 12 |  반복 701 / 1327 | 시간 225[s] | 퍼플렉서티 73.97
# | 에폭 12 |  반복 721 / 1327 | 시간 232[s] | 퍼플렉서티 74.47
# | 에폭 12 |  반복 741 / 1327 | 시간 238[s] | 퍼플렉서티 65.28
# | 에폭 12 |  반복 761 / 1327 | 시간 245[s] | 퍼플렉서티 60.16
# | 에폭 12 |  반복 781 / 1327 | 시간 251[s] | 퍼플렉서티 65.74
# | 에폭 12 |  반복 801 / 1327 | 시간 258[s] | 퍼플렉서티 75.15
# | 에폭 12 |  반복 821 / 1327 | 시간 264[s] | 퍼플렉서티 74.46
# | 에폭 12 |  반복 841 / 1327 | 시간 271[s] | 퍼플렉서티 73.42
# | 에폭 12 |  반복 861 / 1327 | 시간 277[s] | 퍼플렉서티 74.00
# | 에폭 12 |  반복 881 / 1327 | 시간 283[s] | 퍼플렉서티 67.61
# | 에폭 12 |  반복 901 / 1327 | 시간 290[s] | 퍼플렉서티 85.05
# | 에폭 12 |  반복 921 / 1327 | 시간 296[s] | 퍼플렉서티 75.24
# | 에폭 12 |  반복 941 / 1327 | 시간 303[s] | 퍼플렉서티 81.71
# | 에폭 12 |  반복 961 / 1327 | 시간 309[s] | 퍼플렉서티 85.69
# | 에폭 12 |  반복 981 / 1327 | 시간 316[s] | 퍼플렉서티 82.62
# | 에폭 12 |  반복 1001 / 1327 | 시간 322[s] | 퍼플렉서티 71.00
# | 에폭 12 |  반복 1021 / 1327 | 시간 329[s] | 퍼플렉서티 82.40
# | 에폭 12 |  반복 1041 / 1327 | 시간 335[s] | 퍼플렉서티 71.22
# | 에폭 12 |  반복 1061 / 1327 | 시간 342[s] | 퍼플렉서티 68.42
# | 에폭 12 |  반복 1081 / 1327 | 시간 348[s] | 퍼플렉서티 56.28
# | 에폭 12 |  반복 1101 / 1327 | 시간 354[s] | 퍼플렉서티 57.70
# | 에폭 12 |  반복 1121 / 1327 | 시간 361[s] | 퍼플렉서티 78.46
# | 에폭 12 |  반복 1141 / 1327 | 시간 367[s] | 퍼플렉서티 75.54
# | 에폭 12 |  반복 1161 / 1327 | 시간 374[s] | 퍼플렉서티 63.82
# | 에폭 12 |  반복 1181 / 1327 | 시간 380[s] | 퍼플렉서티 71.58
# | 에폭 12 |  반복 1201 / 1327 | 시간 387[s] | 퍼플렉서티 59.17
# | 에폭 12 |  반복 1221 / 1327 | 시간 393[s] | 퍼플렉서티 58.84
# | 에폭 12 |  반복 1241 / 1327 | 시간 399[s] | 퍼플렉서티 71.09
# | 에폭 12 |  반복 1261 / 1327 | 시간 406[s] | 퍼플렉서티 67.42
# | 에폭 12 |  반복 1281 / 1327 | 시간 412[s] | 퍼플렉서티 67.71
# | 에폭 12 |  반복 1301 / 1327 | 시간 419[s] | 퍼플렉서티 84.63
# | 에폭 12 |  반복 1321 / 1327 | 시간 425[s] | 퍼플렉서티 81.64
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  89.17783
# --------------------------------------------------
# | 에폭 13 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 122.24
# | 에폭 13 |  반복 21 / 1327 | 시간 6[s] | 퍼플렉서티 72.89
# | 에폭 13 |  반복 41 / 1327 | 시간 13[s] | 퍼플렉서티 71.07
# | 에폭 13 |  반복 61 / 1327 | 시간 19[s] | 퍼플렉서티 69.77
# | 에폭 13 |  반복 81 / 1327 | 시간 26[s] | 퍼플렉서티 60.94
# | 에폭 13 |  반복 101 / 1327 | 시간 32[s] | 퍼플렉서티 59.45
# | 에폭 13 |  반복 121 / 1327 | 시간 38[s] | 퍼플렉서티 64.14
# | 에폭 13 |  반복 141 / 1327 | 시간 45[s] | 퍼플렉서티 69.28
# | 에폭 13 |  반복 161 / 1327 | 시간 52[s] | 퍼플렉서티 79.65
# | 에폭 13 |  반복 181 / 1327 | 시간 58[s] | 퍼플렉서티 85.37
# | 에폭 13 |  반복 201 / 1327 | 시간 65[s] | 퍼플렉서티 84.29
# | 에폭 13 |  반복 221 / 1327 | 시간 71[s] | 퍼플렉서티 81.72
# | 에폭 13 |  반복 241 / 1327 | 시간 77[s] | 퍼플렉서티 76.87
# | 에폭 13 |  반복 261 / 1327 | 시간 84[s] | 퍼플렉서티 81.70
# | 에폭 13 |  반복 281 / 1327 | 시간 90[s] | 퍼플렉서티 79.17
# | 에폭 13 |  반복 301 / 1327 | 시간 97[s] | 퍼플렉서티 66.33
# | 에폭 13 |  반복 321 / 1327 | 시간 103[s] | 퍼플렉서티 53.75
# | 에폭 13 |  반복 341 / 1327 | 시간 110[s] | 퍼플렉서티 75.48
# | 에폭 13 |  반복 361 / 1327 | 시간 116[s] | 퍼플렉서티 78.43
# | 에폭 13 |  반복 381 / 1327 | 시간 122[s] | 퍼플렉서티 66.28
# | 에폭 13 |  반복 401 / 1327 | 시간 129[s] | 퍼플렉서티 75.44
# | 에폭 13 |  반복 421 / 1327 | 시간 135[s] | 퍼플렉서티 65.29
# | 에폭 13 |  반복 441 / 1327 | 시간 142[s] | 퍼플렉서티 69.77
# | 에폭 13 |  반복 461 / 1327 | 시간 148[s] | 퍼플렉서티 69.72
# | 에폭 13 |  반복 481 / 1327 | 시간 155[s] | 퍼플렉서티 70.05
# | 에폭 13 |  반복 501 / 1327 | 시간 161[s] | 퍼플렉서티 77.47
# | 에폭 13 |  반복 521 / 1327 | 시간 168[s] | 퍼플렉서티 79.19
# | 에폭 13 |  반복 541 / 1327 | 시간 174[s] | 퍼플렉서티 80.51
# | 에폭 13 |  반복 561 / 1327 | 시간 181[s] | 퍼플렉서티 67.40
# | 에폭 13 |  반복 581 / 1327 | 시간 187[s] | 퍼플렉서티 62.63
# | 에폭 13 |  반복 601 / 1327 | 시간 194[s] | 퍼플렉서티 88.88
# | 에폭 13 |  반복 621 / 1327 | 시간 200[s] | 퍼플렉서티 81.84
# | 에폭 13 |  반복 641 / 1327 | 시간 207[s] | 퍼플렉서티 75.43
# | 에폭 13 |  반복 661 / 1327 | 시간 213[s] | 퍼플렉서티 69.91
# | 에폭 13 |  반복 681 / 1327 | 시간 220[s] | 퍼플렉서티 61.10
# | 에폭 13 |  반복 701 / 1327 | 시간 226[s] | 퍼플렉서티 73.20
# | 에폭 13 |  반복 721 / 1327 | 시간 232[s] | 퍼플렉서티 72.46
# | 에폭 13 |  반복 741 / 1327 | 시간 239[s] | 퍼플렉서티 65.09
# | 에폭 13 |  반복 761 / 1327 | 시간 245[s] | 퍼플렉서티 58.45
# | 에폭 13 |  반복 781 / 1327 | 시간 252[s] | 퍼플렉서티 63.82
# | 에폭 13 |  반복 801 / 1327 | 시간 258[s] | 퍼플렉서티 72.57
# | 에폭 13 |  반복 821 / 1327 | 시간 264[s] | 퍼플렉서티 72.91
# | 에폭 13 |  반복 841 / 1327 | 시간 271[s] | 퍼플렉서티 72.70
# | 에폭 13 |  반복 861 / 1327 | 시간 277[s] | 퍼플렉서티 72.03
# | 에폭 13 |  반복 881 / 1327 | 시간 284[s] | 퍼플렉서티 65.55
# | 에폭 13 |  반복 901 / 1327 | 시간 290[s] | 퍼플렉서티 84.57
# | 에폭 13 |  반복 921 / 1327 | 시간 297[s] | 퍼플렉서티 73.35
# | 에폭 13 |  반복 941 / 1327 | 시간 304[s] | 퍼플렉서티 79.33
# | 에폭 13 |  반복 961 / 1327 | 시간 310[s] | 퍼플렉서티 84.41
# | 에폭 13 |  반복 981 / 1327 | 시간 316[s] | 퍼플렉서티 80.91
# | 에폭 13 |  반복 1001 / 1327 | 시간 323[s] | 퍼플렉서티 68.75
# | 에폭 13 |  반복 1021 / 1327 | 시간 329[s] | 퍼플렉서티 79.85
# | 에폭 13 |  반복 1041 / 1327 | 시간 336[s] | 퍼플렉서티 70.06
# | 에폭 13 |  반복 1061 / 1327 | 시간 342[s] | 퍼플렉서티 66.45
# | 에폭 13 |  반복 1081 / 1327 | 시간 348[s] | 퍼플렉서티 54.73
# | 에폭 13 |  반복 1101 / 1327 | 시간 355[s] | 퍼플렉서티 56.48
# | 에폭 13 |  반복 1121 / 1327 | 시간 361[s] | 퍼플렉서티 77.40
# | 에폭 13 |  반복 1141 / 1327 | 시간 368[s] | 퍼플렉서티 74.33
# | 에폭 13 |  반복 1161 / 1327 | 시간 374[s] | 퍼플렉서티 61.75
# | 에폭 13 |  반복 1181 / 1327 | 시간 381[s] | 퍼플렉서티 69.08
# | 에폭 13 |  반복 1201 / 1327 | 시간 387[s] | 퍼플렉서티 56.74
# | 에폭 13 |  반복 1221 / 1327 | 시간 394[s] | 퍼플렉서티 57.83
# | 에폭 13 |  반복 1241 / 1327 | 시간 400[s] | 퍼플렉서티 69.93
# | 에폭 13 |  반복 1261 / 1327 | 시간 407[s] | 퍼플렉서티 66.05
# | 에폭 13 |  반복 1281 / 1327 | 시간 413[s] | 퍼플렉서티 65.95
# | 에폭 13 |  반복 1301 / 1327 | 시간 419[s] | 퍼플렉서티 81.70
# | 에폭 13 |  반복 1321 / 1327 | 시간 426[s] | 퍼플렉서티 81.59
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  87.86655
# --------------------------------------------------
# | 에폭 14 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 117.44
# | 에폭 14 |  반복 21 / 1327 | 시간 6[s] | 퍼플렉서티 71.94
# | 에폭 14 |  반복 41 / 1327 | 시간 13[s] | 퍼플렉서티 68.94
# | 에폭 14 |  반복 61 / 1327 | 시간 19[s] | 퍼플렉서티 68.27
# | 에폭 14 |  반복 81 / 1327 | 시간 25[s] | 퍼플렉서티 58.02
# | 에폭 14 |  반복 101 / 1327 | 시간 32[s] | 퍼플렉서티 57.50
# | 에폭 14 |  반복 121 / 1327 | 시간 39[s] | 퍼플렉서티 62.87
# | 에폭 14 |  반복 141 / 1327 | 시간 45[s] | 퍼플렉서티 67.65
# | 에폭 14 |  반복 161 / 1327 | 시간 52[s] | 퍼플렉서티 78.02
# | 에폭 14 |  반복 181 / 1327 | 시간 58[s] | 퍼플렉서티 83.45
# | 에폭 14 |  반복 201 / 1327 | 시간 65[s] | 퍼플렉서티 81.41
# | 에폭 14 |  반복 221 / 1327 | 시간 71[s] | 퍼플렉서티 79.50
# | 에폭 14 |  반복 241 / 1327 | 시간 78[s] | 퍼플렉서티 74.60
# | 에폭 14 |  반복 261 / 1327 | 시간 84[s] | 퍼플렉서티 78.23
# | 에폭 14 |  반복 281 / 1327 | 시간 90[s] | 퍼플렉서티 77.62
# | 에폭 14 |  반복 301 / 1327 | 시간 97[s] | 퍼플렉서티 64.08
# | 에폭 14 |  반복 321 / 1327 | 시간 103[s] | 퍼플렉서티 51.80
# | 에폭 14 |  반복 341 / 1327 | 시간 110[s] | 퍼플렉서티 74.37
# | 에폭 14 |  반복 361 / 1327 | 시간 116[s] | 퍼플렉서티 77.40
# | 에폭 14 |  반복 381 / 1327 | 시간 123[s] | 퍼플렉서티 64.43
# | 에폭 14 |  반복 401 / 1327 | 시간 129[s] | 퍼플렉서티 72.95
# | 에폭 14 |  반복 421 / 1327 | 시간 136[s] | 퍼플렉서티 62.72
# | 에폭 14 |  반복 441 / 1327 | 시간 142[s] | 퍼플렉서티 67.50
# | 에폭 14 |  반복 461 / 1327 | 시간 148[s] | 퍼플렉서티 68.07
# | 에폭 14 |  반복 481 / 1327 | 시간 155[s] | 퍼플렉서티 68.49
# | 에폭 14 |  반복 501 / 1327 | 시간 161[s] | 퍼플렉서티 74.35
# | 에폭 14 |  반복 521 / 1327 | 시간 168[s] | 퍼플렉서티 77.61
# | 에폭 14 |  반복 541 / 1327 | 시간 174[s] | 퍼플렉서티 78.38
# | 에폭 14 |  반복 561 / 1327 | 시간 181[s] | 퍼플렉서티 64.82
# | 에폭 14 |  반복 581 / 1327 | 시간 187[s] | 퍼플렉서티 61.21
# | 에폭 14 |  반복 601 / 1327 | 시간 194[s] | 퍼플렉서티 87.48
# | 에폭 14 |  반복 621 / 1327 | 시간 200[s] | 퍼플렉서티 81.57
# | 에폭 14 |  반복 641 / 1327 | 시간 207[s] | 퍼플렉서티 74.03
# | 에폭 14 |  반복 661 / 1327 | 시간 213[s] | 퍼플렉서티 69.10
# | 에폭 14 |  반복 681 / 1327 | 시간 220[s] | 퍼플렉서티 58.15
# | 에폭 14 |  반복 701 / 1327 | 시간 226[s] | 퍼플렉서티 71.39
# | 에폭 14 |  반복 721 / 1327 | 시간 232[s] | 퍼플렉서티 70.68
# | 에폭 14 |  반복 741 / 1327 | 시간 239[s] | 퍼플렉서티 63.21
# | 에폭 14 |  반복 761 / 1327 | 시간 245[s] | 퍼플렉서티 56.82
# | 에폭 14 |  반복 781 / 1327 | 시간 252[s] | 퍼플렉서티 62.64
# | 에폭 14 |  반복 801 / 1327 | 시간 258[s] | 퍼플렉서티 69.98
# | 에폭 14 |  반복 821 / 1327 | 시간 265[s] | 퍼플렉서티 71.25
# | 에폭 14 |  반복 841 / 1327 | 시간 271[s] | 퍼플렉서티 70.39
# | 에폭 14 |  반복 861 / 1327 | 시간 278[s] | 퍼플렉서티 69.39
# | 에폭 14 |  반복 881 / 1327 | 시간 284[s] | 퍼플렉서티 64.53
# | 에폭 14 |  반복 901 / 1327 | 시간 291[s] | 퍼플렉서티 82.32
# | 에폭 14 |  반복 921 / 1327 | 시간 297[s] | 퍼플렉서티 72.36
# | 에폭 14 |  반복 941 / 1327 | 시간 303[s] | 퍼플렉서티 77.11
# | 에폭 14 |  반복 961 / 1327 | 시간 310[s] | 퍼플렉서티 81.73
# ...
# | 에폭 36 |  반복 641 / 1327 | 시간 214[s] | 퍼플렉서티 48.29
# | 에폭 36 |  반복 661 / 1327 | 시간 220[s] | 퍼플렉서티 43.49
# | 에폭 36 |  반복 681 / 1327 | 시간 227[s] | 퍼플렉서티 38.39
# | 에폭 36 |  반복 701 / 1327 | 시간 234[s] | 퍼플렉서티 45.70
# | 에폭 36 |  반복 721 / 1327 | 시간 241[s] | 퍼플렉서티 45.65
# | 에폭 36 |  반복 741 / 1327 | 시간 248[s] | 퍼플렉서티 40.66
# | 에폭 36 |  반복 761 / 1327 | 시간 255[s] | 퍼플렉서티 36.83
# | 에폭 36 |  반복 781 / 1327 | 시간 262[s] | 퍼플렉서티 40.60
# | 에폭 36 |  반복 801 / 1327 | 시간 270[s] | 퍼플렉서티 44.68
# | 에폭 36 |  반복 821 / 1327 | 시간 277[s] | 퍼플렉서티 45.90
# | 에폭 36 |  반복 841 / 1327 | 시간 284[s] | 퍼플렉서티 44.80
# | 에폭 36 |  반복 861 / 1327 | 시간 292[s] | 퍼플렉서티 45.10
# | 에폭 36 |  반복 881 / 1327 | 시간 299[s] | 퍼플렉서티 41.69
# | 에폭 36 |  반복 901 / 1327 | 시간 306[s] | 퍼플렉서티 52.72
# | 에폭 36 |  반복 921 / 1327 | 시간 313[s] | 퍼플렉서티 47.21
# | 에폭 36 |  반복 941 / 1327 | 시간 319[s] | 퍼플렉서티 50.29
# | 에폭 36 |  반복 961 / 1327 | 시간 326[s] | 퍼플렉서티 52.09
# | 에폭 36 |  반복 981 / 1327 | 시간 333[s] | 퍼플렉서티 49.40
# | 에폭 36 |  반복 1001 / 1327 | 시간 339[s] | 퍼플렉서티 42.77
# | 에폭 36 |  반복 1021 / 1327 | 시간 346[s] | 퍼플렉서티 48.84
# | 에폭 36 |  반복 1041 / 1327 | 시간 353[s] | 퍼플렉서티 43.88
# | 에폭 36 |  반복 1061 / 1327 | 시간 360[s] | 퍼플렉서티 40.20
# | 에폭 36 |  반복 1081 / 1327 | 시간 366[s] | 퍼플렉서티 33.57
# | 에폭 36 |  반복 1101 / 1327 | 시간 373[s] | 퍼플렉서티 34.56
# | 에폭 36 |  반복 1121 / 1327 | 시간 380[s] | 퍼플렉서티 46.40
# | 에폭 36 |  반복 1141 / 1327 | 시간 387[s] | 퍼플렉서티 44.16
# | 에폭 36 |  반복 1161 / 1327 | 시간 393[s] | 퍼플렉서티 37.48
# | 에폭 36 |  반복 1181 / 1327 | 시간 400[s] | 퍼플렉서티 41.72
# | 에폭 36 |  반복 1201 / 1327 | 시간 407[s] | 퍼플렉서티 34.79
# | 에폭 36 |  반복 1221 / 1327 | 시간 413[s] | 퍼플렉서티 34.67
# | 에폭 36 |  반복 1241 / 1327 | 시간 420[s] | 퍼플렉서티 42.15
# | 에폭 36 |  반복 1261 / 1327 | 시간 427[s] | 퍼플렉서티 40.26
# | 에폭 36 |  반복 1281 / 1327 | 시간 433[s] | 퍼플렉서티 39.86
# | 에폭 36 |  반복 1301 / 1327 | 시간 440[s] | 퍼플렉서티 49.47
# | 에폭 36 |  반복 1321 / 1327 | 시간 447[s] | 퍼플렉서티 48.39
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  80.43261
# --------------------------------------------------
# | 에폭 37 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 79.70
# | 에폭 37 |  반복 21 / 1327 | 시간 6[s] | 퍼플렉서티 49.02
# | 에폭 37 |  반복 41 / 1327 | 시간 13[s] | 퍼플렉서티 47.23
# | 에폭 37 |  반복 61 / 1327 | 시간 20[s] | 퍼플렉서티 46.48
# | 에폭 37 |  반복 81 / 1327 | 시간 26[s] | 퍼플렉서티 40.43
# | 에폭 37 |  반복 101 / 1327 | 시간 33[s] | 퍼플렉서티 39.16
# | 에폭 37 |  반복 121 / 1327 | 시간 40[s] | 퍼플렉서티 42.64
# | 에폭 37 |  반복 141 / 1327 | 시간 46[s] | 퍼플렉서티 46.10
# | 에폭 37 |  반복 161 / 1327 | 시간 53[s] | 퍼플렉서티 52.01
# | 에폭 37 |  반복 181 / 1327 | 시간 60[s] | 퍼플렉서티 56.42
# | 에폭 37 |  반복 201 / 1327 | 시간 66[s] | 퍼플렉서티 55.70
# | 에폭 37 |  반복 221 / 1327 | 시간 73[s] | 퍼플렉서티 53.45
# | 에폭 37 |  반복 241 / 1327 | 시간 80[s] | 퍼플렉서티 50.03
# | 에폭 37 |  반복 261 / 1327 | 시간 86[s] | 퍼플렉서티 53.31
# | 에폭 37 |  반복 281 / 1327 | 시간 93[s] | 퍼플렉서티 52.04
# | 에폭 37 |  반복 301 / 1327 | 시간 100[s] | 퍼플렉서티 42.22
# | 에폭 37 |  반복 321 / 1327 | 시간 107[s] | 퍼플렉서티 34.41
# | 에폭 37 |  반복 341 / 1327 | 시간 113[s] | 퍼플렉서티 48.95
# | 에폭 37 |  반복 361 / 1327 | 시간 120[s] | 퍼플렉서티 49.82
# | 에폭 37 |  반복 381 / 1327 | 시간 127[s] | 퍼플렉서티 42.78
# | 에폭 37 |  반복 401 / 1327 | 시간 133[s] | 퍼플렉서티 48.35
# | 에폭 37 |  반복 421 / 1327 | 시간 140[s] | 퍼플렉서티 42.16
# | 에폭 37 |  반복 441 / 1327 | 시간 147[s] | 퍼플렉서티 43.85
# | 에폭 37 |  반복 461 / 1327 | 시간 154[s] | 퍼플렉서티 44.85
# | 에폭 37 |  반복 481 / 1327 | 시간 160[s] | 퍼플렉서티 45.36
# | 에폭 37 |  반복 501 / 1327 | 시간 167[s] | 퍼플렉서티 48.58
# | 에폭 37 |  반복 521 / 1327 | 시간 174[s] | 퍼플렉서티 50.36
# | 에폭 37 |  반복 541 / 1327 | 시간 181[s] | 퍼플렉서티 50.74
# | 에폭 37 |  반복 561 / 1327 | 시간 187[s] | 퍼플렉서티 42.81
# | 에폭 37 |  반복 581 / 1327 | 시간 194[s] | 퍼플렉서티 39.67
# | 에폭 37 |  반복 601 / 1327 | 시간 201[s] | 퍼플렉서티 57.92
# | 에폭 37 |  반복 621 / 1327 | 시간 207[s] | 퍼플렉서티 51.32
# | 에폭 37 |  반복 641 / 1327 | 시간 214[s] | 퍼플렉서티 48.48
# | 에폭 37 |  반복 661 / 1327 | 시간 221[s] | 퍼플렉서티 43.51
# | 에폭 37 |  반복 681 / 1327 | 시간 227[s] | 퍼플렉서티 38.09
# | 에폭 37 |  반복 701 / 1327 | 시간 234[s] | 퍼플렉서티 45.45
# | 에폭 37 |  반복 721 / 1327 | 시간 241[s] | 퍼플렉서티 46.03
# | 에폭 37 |  반복 741 / 1327 | 시간 247[s] | 퍼플렉서티 40.54
# | 에폭 37 |  반복 761 / 1327 | 시간 254[s] | 퍼플렉서티 37.11
# | 에폭 37 |  반복 781 / 1327 | 시간 261[s] | 퍼플렉서티 39.95
# | 에폭 37 |  반복 801 / 1327 | 시간 268[s] | 퍼플렉서티 44.51
# | 에폭 37 |  반복 821 / 1327 | 시간 274[s] | 퍼플렉서티 45.52
# | 에폭 37 |  반복 841 / 1327 | 시간 281[s] | 퍼플렉서티 44.69
# | 에폭 37 |  반복 861 / 1327 | 시간 288[s] | 퍼플렉서티 45.34
# | 에폭 37 |  반복 881 / 1327 | 시간 294[s] | 퍼플렉서티 41.73
# | 에폭 37 |  반복 901 / 1327 | 시간 301[s] | 퍼플렉서티 52.21
# | 에폭 37 |  반복 921 / 1327 | 시간 308[s] | 퍼플렉서티 46.38
# | 에폭 37 |  반복 941 / 1327 | 시간 314[s] | 퍼플렉서티 50.25
# | 에폭 37 |  반복 961 / 1327 | 시간 321[s] | 퍼플렉서티 51.98
# | 에폭 37 |  반복 981 / 1327 | 시간 328[s] | 퍼플렉서티 49.43
# | 에폭 37 |  반복 1001 / 1327 | 시간 334[s] | 퍼플렉서티 42.39
# | 에폭 37 |  반복 1021 / 1327 | 시간 341[s] | 퍼플렉서티 48.76
# | 에폭 37 |  반복 1041 / 1327 | 시간 348[s] | 퍼플렉서티 42.94
# | 에폭 37 |  반복 1061 / 1327 | 시간 355[s] | 퍼플렉서티 40.53
# | 에폭 37 |  반복 1081 / 1327 | 시간 361[s] | 퍼플렉서티 33.71
# | 에폭 37 |  반복 1101 / 1327 | 시간 368[s] | 퍼플렉서티 34.26
# | 에폭 37 |  반복 1121 / 1327 | 시간 375[s] | 퍼플렉서티 47.04
# | 에폭 37 |  반복 1141 / 1327 | 시간 382[s] | 퍼플렉서티 44.79
# | 에폭 37 |  반복 1161 / 1327 | 시간 388[s] | 퍼플렉서티 37.12
# | 에폭 37 |  반복 1181 / 1327 | 시간 395[s] | 퍼플렉서티 41.96
# | 에폭 37 |  반복 1201 / 1327 | 시간 401[s] | 퍼플렉서티 34.96
# | 에폭 37 |  반복 1221 / 1327 | 시간 408[s] | 퍼플렉서티 34.49
# | 에폭 37 |  반복 1241 / 1327 | 시간 415[s] | 퍼플렉서티 41.97
# | 에폭 37 |  반복 1261 / 1327 | 시간 422[s] | 퍼플렉서티 39.66
# | 에폭 37 |  반복 1281 / 1327 | 시간 428[s] | 퍼플렉서티 40.97
# | 에폭 37 |  반복 1301 / 1327 | 시간 435[s] | 퍼플렉서티 49.60
# | 에폭 37 |  반복 1321 / 1327 | 시간 442[s] | 퍼플렉서티 48.33
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  80.4389
# --------------------------------------------------
# | 에폭 38 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 77.08
# | 에폭 38 |  반복 21 / 1327 | 시간 6[s] | 퍼플렉서티 49.44
# | 에폭 38 |  반복 41 / 1327 | 시간 13[s] | 퍼플렉서티 47.74
# | 에폭 38 |  반복 61 / 1327 | 시간 20[s] | 퍼플렉서티 46.68
# | 에폭 38 |  반복 81 / 1327 | 시간 26[s] | 퍼플렉서티 39.52
# | 에폭 38 |  반복 101 / 1327 | 시간 33[s] | 퍼플렉서티 39.50
# | 에폭 38 |  반복 121 / 1327 | 시간 40[s] | 퍼플렉서티 42.06
# | 에폭 38 |  반복 141 / 1327 | 시간 47[s] | 퍼플렉서티 44.84
# | 에폭 38 |  반복 161 / 1327 | 시간 53[s] | 퍼플렉서티 52.28
# | 에폭 38 |  반복 181 / 1327 | 시간 60[s] | 퍼플렉서티 55.52
# | 에폭 38 |  반복 201 / 1327 | 시간 67[s] | 퍼플렉서티 55.71
# | 에폭 38 |  반복 221 / 1327 | 시간 73[s] | 퍼플렉서티 52.76
# | 에폭 38 |  반복 241 / 1327 | 시간 80[s] | 퍼플렉서티 49.57
# | 에폭 38 |  반복 261 / 1327 | 시간 87[s] | 퍼플렉서티 54.23
# | 에폭 38 |  반복 281 / 1327 | 시간 93[s] | 퍼플렉서티 51.16
# | 에폭 38 |  반복 301 / 1327 | 시간 100[s] | 퍼플렉서티 42.43
# | 에폭 38 |  반복 321 / 1327 | 시간 107[s] | 퍼플렉서티 35.46
# | 에폭 38 |  반복 341 / 1327 | 시간 113[s] | 퍼플렉서티 48.33
# | 에폭 38 |  반복 361 / 1327 | 시간 120[s] | 퍼플렉서티 50.36
# | 에폭 38 |  반복 381 / 1327 | 시간 127[s] | 퍼플렉서티 42.18
# | 에폭 38 |  반복 401 / 1327 | 시간 134[s] | 퍼플렉서티 48.44
# | 에폭 38 |  반복 421 / 1327 | 시간 140[s] | 퍼플렉서티 41.59
# | 에폭 38 |  반복 441 / 1327 | 시간 147[s] | 퍼플렉서티 43.88
# | 에폭 38 |  반복 461 / 1327 | 시간 154[s] | 퍼플렉서티 44.00
# | 에폭 38 |  반복 481 / 1327 | 시간 160[s] | 퍼플렉서티 45.24
# | 에폭 38 |  반복 501 / 1327 | 시간 167[s] | 퍼플렉서티 48.16
# | 에폭 38 |  반복 521 / 1327 | 시간 174[s] | 퍼플렉서티 50.56
# | 에폭 38 |  반복 541 / 1327 | 시간 180[s] | 퍼플렉서티 51.67
# | 에폭 38 |  반복 561 / 1327 | 시간 187[s] | 퍼플렉서티 42.27
# | 에폭 38 |  반복 581 / 1327 | 시간 194[s] | 퍼플렉서티 39.62
# | 에폭 38 |  반복 601 / 1327 | 시간 200[s] | 퍼플렉서티 57.43
# | 에폭 38 |  반복 621 / 1327 | 시간 207[s] | 퍼플렉서티 52.20
# | 에폭 38 |  반복 641 / 1327 | 시간 214[s] | 퍼플렉서티 47.70
# | 에폭 38 |  반복 661 / 1327 | 시간 221[s] | 퍼플렉서티 43.86
# | 에폭 38 |  반복 681 / 1327 | 시간 228[s] | 퍼플렉서티 38.90
# | 에폭 38 |  반복 701 / 1327 | 시간 234[s] | 퍼플렉서티 45.12
# | 에폭 38 |  반복 721 / 1327 | 시간 241[s] | 퍼플렉서티 45.55
# | 에폭 38 |  반복 741 / 1327 | 시간 248[s] | 퍼플렉서티 40.91
# | 에폭 38 |  반복 761 / 1327 | 시간 255[s] | 퍼플렉서티 36.67
# | 에폭 38 |  반복 781 / 1327 | 시간 261[s] | 퍼플렉서티 40.31
# | 에폭 38 |  반복 801 / 1327 | 시간 268[s] | 퍼플렉서티 44.49
# | 에폭 38 |  반복 821 / 1327 | 시간 275[s] | 퍼플렉서티 45.11
# | 에폭 38 |  반복 841 / 1327 | 시간 281[s] | 퍼플렉서티 44.46
# | 에폭 38 |  반복 861 / 1327 | 시간 288[s] | 퍼플렉서티 44.54
# | 에폭 38 |  반복 881 / 1327 | 시간 295[s] | 퍼플렉서티 41.91
# | 에폭 38 |  반복 901 / 1327 | 시간 301[s] | 퍼플렉서티 51.52
# | 에폭 38 |  반복 921 / 1327 | 시간 308[s] | 퍼플렉서티 46.33
# | 에폭 38 |  반복 941 / 1327 | 시간 315[s] | 퍼플렉서티 50.64
# | 에폭 38 |  반복 961 / 1327 | 시간 322[s] | 퍼플렉서티 52.08
# | 에폭 38 |  반복 981 / 1327 | 시간 328[s] | 퍼플렉서티 49.61
# | 에폭 38 |  반복 1001 / 1327 | 시간 335[s] | 퍼플렉서티 42.76
# | 에폭 38 |  반복 1021 / 1327 | 시간 342[s] | 퍼플렉서티 48.62
# | 에폭 38 |  반복 1041 / 1327 | 시간 348[s] | 퍼플렉서티 43.04
# | 에폭 38 |  반복 1061 / 1327 | 시간 355[s] | 퍼플렉서티 40.85
# | 에폭 38 |  반복 1081 / 1327 | 시간 362[s] | 퍼플렉서티 34.11
# | 에폭 38 |  반복 1101 / 1327 | 시간 369[s] | 퍼플렉서티 34.43
# | 에폭 38 |  반복 1121 / 1327 | 시간 375[s] | 퍼플렉서티 47.14
# | 에폭 38 |  반복 1141 / 1327 | 시간 382[s] | 퍼플렉서티 44.33
# | 에폭 38 |  반복 1161 / 1327 | 시간 389[s] | 퍼플렉서티 37.38
# | 에폭 38 |  반복 1181 / 1327 | 시간 395[s] | 퍼플렉서티 41.31
# | 에폭 38 |  반복 1201 / 1327 | 시간 402[s] | 퍼플렉서티 34.74
# | 에폭 38 |  반복 1221 / 1327 | 시간 409[s] | 퍼플렉서티 34.27
# | 에폭 38 |  반복 1241 / 1327 | 시간 416[s] | 퍼플렉서티 41.49
# | 에폭 38 |  반복 1261 / 1327 | 시간 422[s] | 퍼플렉서티 39.69
# | 에폭 38 |  반복 1281 / 1327 | 시간 429[s] | 퍼플렉서티 39.74
# | 에폭 38 |  반복 1301 / 1327 | 시간 436[s] | 퍼플렉서티 49.44
# | 에폭 38 |  반복 1321 / 1327 | 시간 442[s] | 퍼플렉서티 49.13
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  80.429085
# --------------------------------------------------
# | 에폭 39 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 75.72
# | 에폭 39 |  반복 21 / 1327 | 시간 6[s] | 퍼플렉서티 49.66
# | 에폭 39 |  반복 41 / 1327 | 시간 13[s] | 퍼플렉서티 46.64
# | 에폭 39 |  반복 61 / 1327 | 시간 20[s] | 퍼플렉서티 46.14
# | 에폭 39 |  반복 81 / 1327 | 시간 27[s] | 퍼플렉서티 40.27
# | 에폭 39 |  반복 101 / 1327 | 시간 33[s] | 퍼플렉서티 39.14
# | 에폭 39 |  반복 121 / 1327 | 시간 40[s] | 퍼플렉서티 42.63
# | 에폭 39 |  반복 141 / 1327 | 시간 47[s] | 퍼플렉서티 45.78
# | 에폭 39 |  반복 161 / 1327 | 시간 54[s] | 퍼플렉서티 52.55
# | 에폭 39 |  반복 181 / 1327 | 시간 60[s] | 퍼플렉서티 55.98
# | 에폭 39 |  반복 201 / 1327 | 시간 67[s] | 퍼플렉서티 55.47
# | 에폭 39 |  반복 221 / 1327 | 시간 74[s] | 퍼플렉서티 52.19
# | 에폭 39 |  반복 241 / 1327 | 시간 80[s] | 퍼플렉서티 49.81
# | 에폭 39 |  반복 261 / 1327 | 시간 87[s] | 퍼플렉서티 53.43
# | 에폭 39 |  반복 281 / 1327 | 시간 94[s] | 퍼플렉서티 51.25
# | 에폭 39 |  반복 301 / 1327 | 시간 101[s] | 퍼플렉서티 42.31
# | 에폭 39 |  반복 321 / 1327 | 시간 107[s] | 퍼플렉서티 34.78
# | 에폭 39 |  반복 341 / 1327 | 시간 114[s] | 퍼플렉서티 48.62
# | 에폭 39 |  반복 361 / 1327 | 시간 121[s] | 퍼플렉서티 49.86
# | 에폭 39 |  반복 381 / 1327 | 시간 127[s] | 퍼플렉서티 42.29
# | 에폭 39 |  반복 401 / 1327 | 시간 134[s] | 퍼플렉서티 48.80
# | 에폭 39 |  반복 421 / 1327 | 시간 141[s] | 퍼플렉서티 41.78
# | 에폭 39 |  반복 441 / 1327 | 시간 149[s] | 퍼플렉서티 43.50
# | 에폭 39 |  반복 461 / 1327 | 시간 156[s] | 퍼플렉서티 44.40
# | 에폭 39 |  반복 481 / 1327 | 시간 163[s] | 퍼플렉서티 44.94
# | 에폭 39 |  반복 501 / 1327 | 시간 170[s] | 퍼플렉서티 48.50
# | 에폭 39 |  반복 521 / 1327 | 시간 177[s] | 퍼플렉서티 49.82
# | 에폭 39 |  반복 541 / 1327 | 시간 183[s] | 퍼플렉서티 51.55
# | 에폭 39 |  반복 561 / 1327 | 시간 190[s] | 퍼플렉서티 42.37
# | 에폭 39 |  반복 581 / 1327 | 시간 197[s] | 퍼플렉서티 39.50
# | 에폭 39 |  반복 601 / 1327 | 시간 204[s] | 퍼플렉서티 57.96
# | 에폭 39 |  반복 621 / 1327 | 시간 210[s] | 퍼플렉서티 52.18
# | 에폭 39 |  반복 641 / 1327 | 시간 217[s] | 퍼플렉서티 48.14
# | 에폭 39 |  반복 661 / 1327 | 시간 224[s] | 퍼플렉서티 43.10
# | 에폭 39 |  반복 681 / 1327 | 시간 230[s] | 퍼플렉서티 38.99
# | 에폭 39 |  반복 701 / 1327 | 시간 237[s] | 퍼플렉서티 45.94
# | 에폭 39 |  반복 721 / 1327 | 시간 244[s] | 퍼플렉서티 45.32
# | 에폭 39 |  반복 741 / 1327 | 시간 251[s] | 퍼플렉서티 40.41
# | 에폭 39 |  반복 761 / 1327 | 시간 257[s] | 퍼플렉서티 36.62
# | 에폭 39 |  반복 781 / 1327 | 시간 264[s] | 퍼플렉서티 40.32
# | 에폭 39 |  반복 801 / 1327 | 시간 271[s] | 퍼플렉서티 44.29
# | 에폭 39 |  반복 821 / 1327 | 시간 277[s] | 퍼플렉서티 45.61
# | 에폭 39 |  반복 841 / 1327 | 시간 284[s] | 퍼플렉서티 44.95
# | 에폭 39 |  반복 861 / 1327 | 시간 291[s] | 퍼플렉서티 45.54
# | 에폭 39 |  반복 881 / 1327 | 시간 298[s] | 퍼플렉서티 41.00
# | 에폭 39 |  반복 901 / 1327 | 시간 304[s] | 퍼플렉서티 52.41
# | 에폭 39 |  반복 921 / 1327 | 시간 311[s] | 퍼플렉서티 46.80
# | 에폭 39 |  반복 941 / 1327 | 시간 318[s] | 퍼플렉서티 50.09
# | 에폭 39 |  반복 961 / 1327 | 시간 324[s] | 퍼플렉서티 51.79
# | 에폭 39 |  반복 981 / 1327 | 시간 331[s] | 퍼플렉서티 50.08
# | 에폭 39 |  반복 1001 / 1327 | 시간 338[s] | 퍼플렉서티 42.09
# | 에폭 39 |  반복 1021 / 1327 | 시간 344[s] | 퍼플렉서티 49.85
# | 에폭 39 |  반복 1041 / 1327 | 시간 351[s] | 퍼플렉서티 43.20
# | 에폭 39 |  반복 1061 / 1327 | 시간 358[s] | 퍼플렉서티 40.50
# | 에폭 39 |  반복 1081 / 1327 | 시간 365[s] | 퍼플렉서티 33.83
# | 에폭 39 |  반복 1101 / 1327 | 시간 371[s] | 퍼플렉서티 34.30
# | 에폭 39 |  반복 1121 / 1327 | 시간 378[s] | 퍼플렉서티 47.50
# | 에폭 39 |  반복 1141 / 1327 | 시간 385[s] | 퍼플렉서티 45.13
# | 에폭 39 |  반복 1161 / 1327 | 시간 392[s] | 퍼플렉서티 37.66
# | 에폭 39 |  반복 1181 / 1327 | 시간 398[s] | 퍼플렉서티 42.00
# | 에폭 39 |  반복 1201 / 1327 | 시간 405[s] | 퍼플렉서티 34.70
# | 에폭 39 |  반복 1221 / 1327 | 시간 412[s] | 퍼플렉서티 34.85
# | 에폭 39 |  반복 1241 / 1327 | 시간 419[s] | 퍼플렉서티 41.54
# | 에폭 39 |  반복 1261 / 1327 | 시간 425[s] | 퍼플렉서티 40.07
# | 에폭 39 |  반복 1281 / 1327 | 시간 432[s] | 퍼플렉서티 40.67
# | 에폭 39 |  반복 1301 / 1327 | 시간 439[s] | 퍼플렉서티 50.49
# | 에폭 39 |  반복 1321 / 1327 | 시간 445[s] | 퍼플렉서티 48.49
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  80.41697
# --------------------------------------------------
# | 에폭 40 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 79.25
# | 에폭 40 |  반복 21 / 1327 | 시간 6[s] | 퍼플렉서티 49.12
# | 에폭 40 |  반복 41 / 1327 | 시간 13[s] | 퍼플렉서티 47.07
# | 에폭 40 |  반복 61 / 1327 | 시간 20[s] | 퍼플렉서티 46.48
# | 에폭 40 |  반복 81 / 1327 | 시간 27[s] | 퍼플렉서티 39.79
# | 에폭 40 |  반복 101 / 1327 | 시간 33[s] | 퍼플렉서티 39.60
# | 에폭 40 |  반복 121 / 1327 | 시간 40[s] | 퍼플렉서티 42.30
# | 에폭 40 |  반복 141 / 1327 | 시간 47[s] | 퍼플렉서티 45.79
# | 에폭 40 |  반복 161 / 1327 | 시간 53[s] | 퍼플렉서티 52.67
# | 에폭 40 |  반복 181 / 1327 | 시간 60[s] | 퍼플렉서티 55.27
# | 에폭 40 |  반복 201 / 1327 | 시간 67[s] | 퍼플렉서티 55.09
# | 에폭 40 |  반복 221 / 1327 | 시간 74[s] | 퍼플렉서티 52.79
# | 에폭 40 |  반복 241 / 1327 | 시간 80[s] | 퍼플렉서티 49.92
# | 에폭 40 |  반복 261 / 1327 | 시간 87[s] | 퍼플렉서티 52.94
# | 에폭 40 |  반복 281 / 1327 | 시간 94[s] | 퍼플렉서티 51.95
# | 에폭 40 |  반복 301 / 1327 | 시간 100[s] | 퍼플렉서티 42.47
# | 에폭 40 |  반복 321 / 1327 | 시간 107[s] | 퍼플렉서티 34.75
# | 에폭 40 |  반복 341 / 1327 | 시간 114[s] | 퍼플렉서티 48.55
# | 에폭 40 |  반복 361 / 1327 | 시간 121[s] | 퍼플렉서티 50.61
# | 에폭 40 |  반복 381 / 1327 | 시간 127[s] | 퍼플렉서티 42.29
# | 에폭 40 |  반복 401 / 1327 | 시간 134[s] | 퍼플렉서티 48.37
# | 에폭 40 |  반복 421 / 1327 | 시간 141[s] | 퍼플렉서티 41.93
# | 에폭 40 |  반복 441 / 1327 | 시간 147[s] | 퍼플렉서티 43.86
# | 에폭 40 |  반복 461 / 1327 | 시간 154[s] | 퍼플렉서티 44.89
# | 에폭 40 |  반복 481 / 1327 | 시간 161[s] | 퍼플렉서티 45.87
# | 에폭 40 |  반복 501 / 1327 | 시간 168[s] | 퍼플렉서티 48.79
# | 에폭 40 |  반복 521 / 1327 | 시간 174[s] | 퍼플렉서티 50.09
# | 에폭 40 |  반복 541 / 1327 | 시간 181[s] | 퍼플렉서티 50.00
# | 에폭 40 |  반복 561 / 1327 | 시간 188[s] | 퍼플렉서티 42.93
# | 에폭 40 |  반복 581 / 1327 | 시간 194[s] | 퍼플렉서티 39.09
# | 에폭 40 |  반복 601 / 1327 | 시간 201[s] | 퍼플렉서티 58.59
# | 에폭 40 |  반복 621 / 1327 | 시간 208[s] | 퍼플렉서티 51.83
# | 에폭 40 |  반복 641 / 1327 | 시간 215[s] | 퍼플렉서티 48.37
# | 에폭 40 |  반복 661 / 1327 | 시간 221[s] | 퍼플렉서티 43.47
# | 에폭 40 |  반복 681 / 1327 | 시간 228[s] | 퍼플렉서티 38.38
# | 에폭 40 |  반복 701 / 1327 | 시간 235[s] | 퍼플렉서티 45.12
# | 에폭 40 |  반복 721 / 1327 | 시간 241[s] | 퍼플렉서티 45.04
# | 에폭 40 |  반복 741 / 1327 | 시간 248[s] | 퍼플렉서티 40.88
# | 에폭 40 |  반복 761 / 1327 | 시간 255[s] | 퍼플렉서티 36.84
# | 에폭 40 |  반복 781 / 1327 | 시간 261[s] | 퍼플렉서티 40.78
# | 에폭 40 |  반복 801 / 1327 | 시간 268[s] | 퍼플렉서티 44.70
# | 에폭 40 |  반복 821 / 1327 | 시간 275[s] | 퍼플렉서티 45.55
# | 에폭 40 |  반복 841 / 1327 | 시간 282[s] | 퍼플렉서티 45.13
# | 에폭 40 |  반복 861 / 1327 | 시간 288[s] | 퍼플렉서티 44.59
# | 에폭 40 |  반복 881 / 1327 | 시간 295[s] | 퍼플렉서티 41.31
# | 에폭 40 |  반복 901 / 1327 | 시간 302[s] | 퍼플렉서티 52.87
# | 에폭 40 |  반복 921 / 1327 | 시간 308[s] | 퍼플렉서티 46.41
# | 에폭 40 |  반복 941 / 1327 | 시간 315[s] | 퍼플렉서티 50.94
# | 에폭 40 |  반복 961 / 1327 | 시간 322[s] | 퍼플렉서티 51.82
# | 에폭 40 |  반복 981 / 1327 | 시간 329[s] | 퍼플렉서티 49.77
# | 에폭 40 |  반복 1001 / 1327 | 시간 335[s] | 퍼플렉서티 42.84
# | 에폭 40 |  반복 1021 / 1327 | 시간 342[s] | 퍼플렉서티 48.62
# | 에폭 40 |  반복 1041 / 1327 | 시간 349[s] | 퍼플렉서티 43.13
# | 에폭 40 |  반복 1061 / 1327 | 시간 355[s] | 퍼플렉서티 40.63
# | 에폭 40 |  반복 1081 / 1327 | 시간 362[s] | 퍼플렉서티 33.07
# | 에폭 40 |  반복 1101 / 1327 | 시간 369[s] | 퍼플렉서티 34.72
# | 에폭 40 |  반복 1121 / 1327 | 시간 376[s] | 퍼플렉서티 46.77
# | 에폭 40 |  반복 1141 / 1327 | 시간 382[s] | 퍼플렉서티 44.63
# | 에폭 40 |  반복 1161 / 1327 | 시간 389[s] | 퍼플렉서티 37.60
# | 에폭 40 |  반복 1181 / 1327 | 시간 396[s] | 퍼플렉서티 41.63
# | 에폭 40 |  반복 1201 / 1327 | 시간 403[s] | 퍼플렉서티 34.51
# | 에폭 40 |  반복 1221 / 1327 | 시간 410[s] | 퍼플렉서티 34.51
# | 에폭 40 |  반복 1241 / 1327 | 시간 416[s] | 퍼플렉서티 41.86
# | 에폭 40 |  반복 1261 / 1327 | 시간 423[s] | 퍼플렉서티 39.65
# | 에폭 40 |  반복 1281 / 1327 | 시간 430[s] | 퍼플렉서티 40.50
# | 에폭 40 |  반복 1301 / 1327 | 시간 437[s] | 퍼플렉서티 49.53
# | 에폭 40 |  반복 1321 / 1327 | 시간 443[s] | 퍼플렉서티 48.71
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  80.41435
# --------------------------------------------------
# 퍼플렉서티 평가 중 ...
# 234 / 235
# 테스트 퍼플렉서티:  76.33472
